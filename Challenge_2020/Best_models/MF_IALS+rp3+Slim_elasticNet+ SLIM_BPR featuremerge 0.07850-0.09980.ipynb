# %% [markdown]
# # Data loading
# Next cells are used to load the data we need.

# %%
import os

os.environ["MKL_NUM_THREADS"] = "1" # export MKL_NUM_THREADS=1

import pandas as pd
import numpy as np 
import scipy.sparse as sps
import sys
import matplotlib.pyplot as plt
sys.path.append('../../')

# %%
#data which contains users (row), items(col) and implicit interaction (data)
dataset = pd.read_csv('../data_train.csv')
dataset
# Out:
#          row    col  data
# 0          0  10080   1.0
# 1          0  19467   1.0
# 2          1   2665   1.0
# 3          1   7494   1.0
# 4          1  17068   1.0
# ...      ...    ...   ...
# 113263  7945   2476   1.0
# 113264  7945  12319   1.0
# 113265  7945  21384   1.0
# 113266  7946   8699   1.0
# 113267  7946  19178   1.0
#
# [113268 rows x 3 columns]

# %% [markdown]
# # Data pre-processing
# Pre-processing of data to check for missing users, items ecc...

# %%
users = dataset.row
items = dataset.col
data = dataset.data
URM_all = sps.coo_matrix((data, (users, items)))
URM_all = URM_all.tocsr() #fast row access -> fast access to users 
URM_all.shape
# Out:
# (7947, 25975)

# %%
ICM_df = pd.read_csv('../data_ICM_title_abstract.csv')
ICM_df
# Out:
#           row    col      data
# 0           0   1185  1.015524
# 1           0   2507  0.459024
# 2           0   3534  0.227742
# 3           0   8766  0.501549
# 4           0  10862  0.297011
# ...       ...    ...       ...
# 490686  25974  12554  0.963016
# 490687  25974  13003  0.104613
# 490688  25974  16236  0.118760
# 490689  25974  18797  0.363301
# 490690  25974  19629  0.129141
#
# [490691 rows x 3 columns]

# %%
items = ICM_df.row
features = ICM_df.col
data = ICM_df.data
ICM_all = sps.coo_matrix((data, (items, features)))
ICM_all = ICM_all.tocsr() #fast row access -> fast access to users 
ICM_all.shape
# Out:
# (25975, 20000)

# %%
from Base.Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.8)
evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
# Out:
# Warning: 73 (0.92 %) of 7947 users have no train items
# Warning: 2270 (28.56 %) of 7947 users have no sampled items

# %%
from MatrixFactorization.IALSRecommender_implicit import IALSRecommender_implicit

#Trial 22 finished with value: 0.07502862236249128 and parameters: {'n_factors': 867, 'regularization': 0.7451746230098858, 'iterations': 74, 'weight': 0.5512468009549221}. Best is trial 22 with value: 0.07502862236249128.[0m
#printing self map vector:  [0.07496821 0.07736574 0.07275191]
#printing MAP:  0.07502862236249128

#current best parameters. Tune again near these values
#printing MAP:  0.07395163955000743
#{'n_factors': 767, 'regularization': 0.6762816208423306, 'iterations': 69, 'weight': 0.5686851029710857}

#{'n_factors': 779, 'regularization': 0.41829264231590485, 'iterations': 72, 'weight': 0.533979793083854}

URM_train_ICM_all_IALS = sps.vstack([URM_all*(1-0.5293971458364172), ICM_all.T*0.5293971458364172])
recommender_IALS = IALSRecommender_implicit(URM_train_ICM_all_IALS)
recommender_IALS.fit(n_factors = 768, regularization = 0.4489004525533907, iterations=76)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-5f84462b6158> in <module>
# ----> 1 from MatrixFactorization.IALSRecommender_implicit import IALSRecommender_implicit
#       2
#       3 #Trial 22 finished with value: 0.07502862236249128 and parameters: {'n_factors': 867, 'regularization': 0.7451746230098858, 'iterations': 74, 'weight': 0.5512468009549221}. Best is trial 22 with value: 0.07502862236249128.
#       4 #printing self map vector:  [0.07496821 0.07736574 0.07275191]
#       5 #printing MAP:  0.07502862236249128
#
# ~/Desktop/Università/Recommender Systems/Recatommender-Systems-Challenge/MatrixFactorization/IALSRecommender_implicit.py in <module>
#      10 from Base.Incremental_Training_Early_Stopping import Incremental_Training_Early_Stopping
#      11 from Base.Recommender_utils import check_matrix
# ---> 12 import implicit
#      13 from tqdm import tqdm
#      14 import numpy as np
#
# ModuleNotFoundError: No module named 'implicit'

# %%
from GraphBased.RP3betaRecommender import RP3betaRecommender
#already 3 crossed validated these values
URM_train_ICM_all_RP3 = sps.vstack([URM_all, ICM_all.T])
recommender_rp3Beta = RP3betaRecommender(URM_train_ICM_all_RP3)
recommender_rp3Beta.fit(topK=207, alpha = 0.36128728066686633, beta=0.26052832791376884, implicit = False) 
#recommender_rp3Beta.URM_train = URM_train
# Out:
# RP3betaRecommender: URM Detected 2 (0.01 %) cold users.

# %%
from SLIM_ElasticNet.SLIMElasticNetRecommender import SLIMElasticNetRecommender

URM_train_ICM_all_SLIM = sps.vstack([URM_all*(1-0.421), ICM_all.T*0.421])
recommender_SLIM = SLIMElasticNetRecommender(URM_train_ICM_all_SLIM)
recommender_SLIM.fit(topK=996, alpha = 0.000182, l1_ratio = 4.459e-06)
recommender_SLIM.W_sparse.data = np.power(recommender_SLIM.W_sparse.data, 0.8546)
# Out:
# SLIMElasticNetRecommender: URM Detected 2 (0.01 %) cold users.
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0015980475582182407, tolerance: 0.0008219736628234386
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.000999618205241859, tolerance: 0.0005707712844014168
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.001118759042583406, tolerance: 0.0006786418962292373
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0051667699590325356, tolerance: 0.0010425166692584753
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.000446205580374226, tolerance: 8.584411261836067e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0009018422570079565, tolerance: 0.00035722440225072205
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0007047670078463852, tolerance: 0.00039366239798255265
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.164664515992627e-05, tolerance: 6.548273813677952e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004367256537079811, tolerance: 0.0013173326151445508
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0193780604749918, tolerance: 0.0022235815413296223
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0007175926002673805, tolerance: 0.0004597740189637989
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.576884283684194e-05, tolerance: 7.310928776860237e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05097823217511177, tolerance: 0.003152445424348116
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0037454278208315372, tolerance: 0.0008739424520172179
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0005425681592896581, tolerance: 0.0002546148607507348
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006677256315015256, tolerance: 0.00024509677314199507
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00023231352679431438, tolerance: 0.0001580359530635178
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05795301869511604, tolerance: 0.0027717920020222664
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15378187596797943, tolerance: 0.004884388763457537
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0001488774869358167, tolerance: 6.748086889274418e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0010996609926223755, tolerance: 0.0003456353151705116
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0004257403197698295, tolerance: 0.00010785731865325943
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028335094451904297, tolerance: 0.0020859423093497753
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.021937821060419083, tolerance: 0.0019466689554974437
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00032768427627161145, tolerance: 0.0001564984122524038
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0053526870906353, tolerance: 0.0016262107528746128
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003599649528041482, tolerance: 0.0009461870649829507
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0053808195516467094, tolerance: 0.0015623359940946102
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006352139171212912, tolerance: 0.0003283846308477223
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005259994883090258, tolerance: 0.001355574233457446
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.000645180291030556, tolerance: 0.00016856550064403564
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00458202650770545, tolerance: 0.0012146454537287354
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005644007120281458, tolerance: 0.002027918817475438
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00018819030083250254, tolerance: 0.0001539211516501382
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002046594163402915, tolerance: 0.0006375000230036676
#   model = cd_fast.sparse_enet_coordinate_descent(
# SLIMElasticNetRecommender: Processed 4417 ( 17.00% ) in 5.00 min. Items per second: 14.72
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06030762940645218, tolerance: 0.003089803270995617
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04852363467216492, tolerance: 0.0028581060469150543
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.011610894463956356, tolerance: 0.0016355362022295594
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005264922045171261, tolerance: 0.0018699169158935547
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016356879845261574, tolerance: 0.003160524647682905
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002381714293733239, tolerance: 0.0005219241720624268
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.28200798726175e-05, tolerance: 4.468773113330826e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0002262518828501925, tolerance: 3.733183621079661e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0072615682147443295, tolerance: 0.0007328403298743069
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04132791608572006, tolerance: 0.003678934881463647
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0014604805037379265, tolerance: 0.0004918076447211206
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.026205003261566162, tolerance: 0.0029881508089601994
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004519001580774784, tolerance: 0.0015557485166937113
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0340983085334301, tolerance: 0.0027460497803986073
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002077418379485607, tolerance: 0.0008692285045981407
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0009638391784392297, tolerance: 0.0007681635906919837
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0037936095613986254, tolerance: 0.0026067798025906086
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005632302258163691, tolerance: 0.001661194022744894
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0019482405623421073, tolerance: 0.000888197508174926
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0003566534142009914, tolerance: 0.0001513584575150162
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0005326810060068965, tolerance: 0.00016311032231897116
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.29064443707466125, tolerance: 0.0035757666919380426
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007288267835974693, tolerance: 0.0015643468359485269
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00029477570205926895, tolerance: 0.00023771719133947045
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005830544512718916, tolerance: 0.0012716001365333796
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0010902611538767815, tolerance: 0.00014329867553897202
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0027945353649556637, tolerance: 0.0007433859282173216
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00842114258557558, tolerance: 0.003221447579562664
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00044281911686994135, tolerance: 0.00021266106341499835
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0019465519580990076, tolerance: 0.0010638509411364794
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05514955893158913, tolerance: 0.0022429870441555977
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.015943337231874466, tolerance: 0.0030765593983232975
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0016062689246609807, tolerance: 0.00014094605285208672
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.000348721572663635, tolerance: 0.00014615096733905375
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010092857293784618, tolerance: 0.001911237253807485
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00014951478806324303, tolerance: 8.075987716438249e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002222910290583968, tolerance: 0.000785773154348135
#   model = cd_fast.sparse_enet_coordinate_descent(
# SLIMElasticNetRecommender: Processed 8839 ( 34.03% ) in 10.00 min. Items per second: 14.73
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009897281415760517, tolerance: 0.001809288514778018
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009771161712706089, tolerance: 0.001953224651515484
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006803623400628567, tolerance: 0.00010161322279600427
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009797196835279465, tolerance: 0.001649359823204577
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009868799708783627, tolerance: 0.0014563993318006396
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02479153499007225, tolerance: 0.0020142216235399246
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0027149412781000137, tolerance: 0.0014965701848268509
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0049544330686330795, tolerance: 0.0009087619837373495
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006843621958978474, tolerance: 0.0002881475375033915
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.3207640647888184, tolerance: 0.006234701257199049
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.001045516226440668, tolerance: 0.0005636218120343983
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03551233187317848, tolerance: 0.0028279596008360386
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.029079634696245193, tolerance: 0.0028705305885523558
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.000660192221403122, tolerance: 0.0005382741219364107
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0014124060980975628, tolerance: 0.0006188256083987653
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006658133585005999, tolerance: 0.0013559787767007947
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.31875574588775635, tolerance: 0.0036962844897061586
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002629100577905774, tolerance: 0.0012309288140386343
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.8675801753997803, tolerance: 0.005439062137156725
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0036907470785081387, tolerance: 0.0007510636933147907
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010983684100210667, tolerance: 0.0013784284237772226
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018017373979091644, tolerance: 0.002676121424883604
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09105642139911652, tolerance: 0.0032292434480041265
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0024199013132601976, tolerance: 0.0011926101287826896
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00010527645645197481, tolerance: 9.124173811869696e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01777711696922779, tolerance: 0.0016262452118098736
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002428479725494981, tolerance: 0.0009423248120583594
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02173772267997265, tolerance: 0.0026132191997021437
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0024427396710962057, tolerance: 0.001370366895571351
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010800118558108807, tolerance: 0.0028233162593096495
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0016521418001502752, tolerance: 0.0009789273608475924
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.22865189611911774, tolerance: 0.004233043175190687
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003052934305742383, tolerance: 0.0013522910885512829
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03013637103140354, tolerance: 0.002010129392147064
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0011833610478788614, tolerance: 0.00022685046133119613
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004293294623494148, tolerance: 0.0011803725501522422
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008236869238317013, tolerance: 0.0026520462706685066
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004509332589805126, tolerance: 0.000932845170609653
#   model = cd_fast.sparse_enet_coordinate_descent(
# SLIMElasticNetRecommender: Processed 13241 ( 50.98% ) in 15.00 min. Items per second: 14.71
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0011626173509284854, tolerance: 0.0006640650681219995
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00040397729026153684, tolerance: 0.0001137151921284385
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019733477383852005, tolerance: 0.002973661758005619
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0001377844309899956, tolerance: 7.068175182212144e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0013262683060020208, tolerance: 0.0008069387404248118
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0021973103284835815, tolerance: 0.0008212831453420222
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006511419196613133, tolerance: 0.0004533924802672118
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.014813251793384552, tolerance: 0.0014320090413093567
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0026074531488120556, tolerance: 0.0003793197392951697
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006555677973665297, tolerance: 0.0003766182635445148
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0019000839674845338, tolerance: 0.0006733775953762233
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00023419101489707828, tolerance: 0.0001387995871482417
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0009929848602041602, tolerance: 6.805863085901365e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0001969018194358796, tolerance: 0.00010236172238364816
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.10570357739925385, tolerance: 0.003592802444472909
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.88563590706326e-05, tolerance: 6.786690937587991e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0007000453770160675, tolerance: 0.0006773137720301747
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0011418501380831003, tolerance: 0.0003876357222907245
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005808443762362003, tolerance: 0.0012943566543981433
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09331244230270386, tolerance: 0.0021177923772484064
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005616090260446072, tolerance: 0.0009600179619155824
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00013467491953633726, tolerance: 7.570062734885141e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02399422973394394, tolerance: 0.0017189098289236426
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00017587847833056003, tolerance: 3.431292134337127e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05592748150229454, tolerance: 0.0036509970668703318
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003707147901877761, tolerance: 0.0010890956036746502
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00017269565432798117, tolerance: 6.87050269334577e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00013895254232920706, tolerance: 0.00011389359860913828
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0002642663021106273, tolerance: 0.00021741453383583575
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0011447817087173462, tolerance: 0.0002108273474732414
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0003399542474653572, tolerance: 8.295533916680142e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00024831024347804487, tolerance: 9.676443733042106e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0005663784104399383, tolerance: 0.00021814722276758403
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00022374636319000274, tolerance: 0.00011467575677670538
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00033894344232976437, tolerance: 0.00015010943752713501
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0015445624012500048, tolerance: 0.0004843823262490332
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002741089090704918, tolerance: 0.001218361547216773
#   model = cd_fast.sparse_enet_coordinate_descent(
# ...
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0005056667141616344, tolerance: 0.0001723509340081364
#   model = cd_fast.sparse_enet_coordinate_descent(
# SLIMElasticNetRecommender: Processed 21270 ( 81.89% ) in 25.00 min. Items per second: 14.18
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00011228292714804411, tolerance: 0.00010085513349622488
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0003864437167067081, tolerance: 0.00017302924243267626
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.05451829358935356, tolerance: 0.0038821203634142876
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.000602254003752023, tolerance: 0.00021323547116480768
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0017623540479689837, tolerance: 0.0006693197647109628
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007410510443150997, tolerance: 0.001950539881363511
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002728258026763797, tolerance: 0.0012134457938373089
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004541425500065088, tolerance: 0.0015368710737675428
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0007207808084785938, tolerance: 0.00020043429685756564
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.011437509208917618, tolerance: 0.0029731113463640213
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.63729985919781e-05, tolerance: 6.0442958783824e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003709122072905302, tolerance: 0.0015752706676721573
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00035974945058114827, tolerance: 0.0002387262211414054
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04830101877450943, tolerance: 0.0034611655864864588
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0025325454771518707, tolerance: 0.0009729083976708353
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.011457731947302818, tolerance: 0.0018557090079411864
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00019964597595389932, tolerance: 9.802176646189764e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.001085472060367465, tolerance: 0.0001353389088762924
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009843721054494381, tolerance: 0.001477984362281859
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017186151817440987, tolerance: 0.0020352331921458244
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003055616281926632, tolerance: 0.0009760587709024549
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0022057993337512016, tolerance: 0.0014600566355511546
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13423605263233185, tolerance: 0.004060257691890001
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003361350856721401, tolerance: 0.0013088833075016737
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0002586801128927618, tolerance: 0.0001529037836007774
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08851063996553421, tolerance: 0.002609488321468234
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01030969899147749, tolerance: 0.002653030911460519
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018054736778140068, tolerance: 0.002627419540658593
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12402985244989395, tolerance: 0.002236056374385953
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.000279681698884815, tolerance: 0.0001435626036254689
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08867572247982025, tolerance: 0.013205056078732014
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0007355554262176156, tolerance: 0.00022174433979671448
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0011534846853464842, tolerance: 8.42883819132112e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.029060952365398407, tolerance: 0.00295088323764503
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00025684875436127186, tolerance: 0.00023406490799970925
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02699408307671547, tolerance: 0.00167048757430166
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006891115917824209, tolerance: 0.0005163168534636497
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0013343443861231208, tolerance: 0.0006732761394232512
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.021261212183163e-05, tolerance: 7.357281720032915e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# SLIMElasticNetRecommender: Processed 25229 ( 97.13% ) in 30.00 min. Items per second: 14.01
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.256663179257885e-05, tolerance: 3.487366120680235e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0756823942065239, tolerance: 0.008016743697226048
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07505739480257034, tolerance: 0.0018809903413057327
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.620516061782837, tolerance: 0.007426316849887371
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003118372056633234, tolerance: 0.0007116304477676749
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006010692450217903, tolerance: 0.00022016357979737222
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0005887550069019198, tolerance: 0.00016123570094350725
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004415674600750208, tolerance: 0.0007731912191957235
#   model = cd_fast.sparse_enet_coordinate_descent(
# SLIMElasticNetRecommender: Processed 25975 ( 100.00% ) in 30.97 min. Items per second: 13.98

# %%
from SLIM_BPR.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython

URM_train_ICM_all_SLIM = sps.vstack([URM_all*(1- 0.6229636472829045), ICM_all.T* 0.6229636472829045])
recommender_SLIM_BPR = SLIM_BPR_Cython(URM_train_ICM_all_SLIM, recompile_cython=False, verbose=False)
recommender_SLIM_BPR.fit(epochs=87, sgd_mode= "adam", learning_rate= 6.12252603066224e-06, topK = 805, batch_size = 35, lambda_i=3.0399585540912118e-05, lambda_j=0.00012176512055401498 )
# Out:
# Unable to read memory status: list index out of range
# SLIM_BPR_Recommender: Epoch 1 of 87. Elapsed time 0.08 sec
# SLIM_BPR_Recommender: Epoch 2 of 87. Elapsed time 0.17 sec
# SLIM_BPR_Recommender: Epoch 3 of 87. Elapsed time 0.25 sec
# SLIM_BPR_Recommender: Epoch 4 of 87. Elapsed time 0.34 sec
# SLIM_BPR_Recommender: Epoch 5 of 87. Elapsed time 0.42 sec
# SLIM_BPR_Recommender: Epoch 6 of 87. Elapsed time 0.50 sec
# SLIM_BPR_Recommender: Epoch 7 of 87. Elapsed time 0.58 sec
# SLIM_BPR_Recommender: Epoch 8 of 87. Elapsed time 0.67 sec
# SLIM_BPR_Recommender: Epoch 9 of 87. Elapsed time 0.75 sec
# SLIM_BPR_Recommender: Epoch 10 of 87. Elapsed time 0.83 sec
# SLIM_BPR_Recommender: Epoch 11 of 87. Elapsed time 0.92 sec
# SLIM_BPR_Recommender: Epoch 12 of 87. Elapsed time 1.00 sec
# SLIM_BPR_Recommender: Epoch 13 of 87. Elapsed time 1.09 sec
# SLIM_BPR_Recommender: Epoch 14 of 87. Elapsed time 1.17 sec
# SLIM_BPR_Recommender: Epoch 15 of 87. Elapsed time 1.26 sec
# SLIM_BPR_Recommender: Epoch 16 of 87. Elapsed time 1.34 sec
# SLIM_BPR_Recommender: Epoch 17 of 87. Elapsed time 1.43 sec
# SLIM_BPR_Recommender: Epoch 18 of 87. Elapsed time 1.51 sec
# SLIM_BPR_Recommender: Epoch 19 of 87. Elapsed time 1.60 sec
# SLIM_BPR_Recommender: Epoch 20 of 87. Elapsed time 1.68 sec
# SLIM_BPR_Recommender: Epoch 21 of 87. Elapsed time 1.77 sec
# SLIM_BPR_Recommender: Epoch 22 of 87. Elapsed time 1.85 sec
# SLIM_BPR_Recommender: Epoch 23 of 87. Elapsed time 1.93 sec
# SLIM_BPR_Recommender: Epoch 24 of 87. Elapsed time 2.02 sec
# SLIM_BPR_Recommender: Epoch 25 of 87. Elapsed time 2.10 sec
# SLIM_BPR_Recommender: Epoch 26 of 87. Elapsed time 2.18 sec
# SLIM_BPR_Recommender: Epoch 27 of 87. Elapsed time 2.27 sec
# SLIM_BPR_Recommender: Epoch 28 of 87. Elapsed time 2.35 sec
# SLIM_BPR_Recommender: Epoch 29 of 87. Elapsed time 2.44 sec
# SLIM_BPR_Recommender: Epoch 30 of 87. Elapsed time 2.52 sec
# SLIM_BPR_Recommender: Epoch 31 of 87. Elapsed time 2.60 sec
# SLIM_BPR_Recommender: Epoch 32 of 87. Elapsed time 2.69 sec
# SLIM_BPR_Recommender: Epoch 33 of 87. Elapsed time 2.77 sec
# SLIM_BPR_Recommender: Epoch 34 of 87. Elapsed time 2.85 sec
# SLIM_BPR_Recommender: Epoch 35 of 87. Elapsed time 2.93 sec
# SLIM_BPR_Recommender: Epoch 36 of 87. Elapsed time 3.02 sec
# SLIM_BPR_Recommender: Epoch 37 of 87. Elapsed time 3.10 sec
# SLIM_BPR_Recommender: Epoch 38 of 87. Elapsed time 3.19 sec
# SLIM_BPR_Recommender: Epoch 39 of 87. Elapsed time 3.27 sec
# SLIM_BPR_Recommender: Epoch 40 of 87. Elapsed time 3.35 sec
# SLIM_BPR_Recommender: Epoch 41 of 87. Elapsed time 3.44 sec
# SLIM_BPR_Recommender: Epoch 42 of 87. Elapsed time 3.52 sec
# SLIM_BPR_Recommender: Epoch 43 of 87. Elapsed time 3.60 sec
# SLIM_BPR_Recommender: Epoch 44 of 87. Elapsed time 3.69 sec
# SLIM_BPR_Recommender: Epoch 45 of 87. Elapsed time 3.77 sec
# SLIM_BPR_Recommender: Epoch 46 of 87. Elapsed time 3.85 sec
# SLIM_BPR_Recommender: Epoch 47 of 87. Elapsed time 3.94 sec
# SLIM_BPR_Recommender: Epoch 48 of 87. Elapsed time 4.02 sec
# SLIM_BPR_Recommender: Epoch 49 of 87. Elapsed time 4.10 sec
# SLIM_BPR_Recommender: Epoch 50 of 87. Elapsed time 4.19 sec
# SLIM_BPR_Recommender: Epoch 51 of 87. Elapsed time 4.27 sec
# SLIM_BPR_Recommender: Epoch 52 of 87. Elapsed time 4.36 sec
# SLIM_BPR_Recommender: Epoch 53 of 87. Elapsed time 4.44 sec
# SLIM_BPR_Recommender: Epoch 54 of 87. Elapsed time 4.53 sec
# SLIM_BPR_Recommender: Epoch 55 of 87. Elapsed time 4.61 sec
# SLIM_BPR_Recommender: Epoch 56 of 87. Elapsed time 4.69 sec
# SLIM_BPR_Recommender: Epoch 57 of 87. Elapsed time 4.78 sec
# SLIM_BPR_Recommender: Epoch 58 of 87. Elapsed time 4.87 sec
# SLIM_BPR_Recommender: Epoch 59 of 87. Elapsed time 4.95 sec
# SLIM_BPR_Recommender: Epoch 60 of 87. Elapsed time 5.04 sec
# SLIM_BPR_Recommender: Epoch 61 of 87. Elapsed time 5.13 sec
# SLIM_BPR_Recommender: Epoch 62 of 87. Elapsed time 5.21 sec
# SLIM_BPR_Recommender: Epoch 63 of 87. Elapsed time 5.30 sec
# SLIM_BPR_Recommender: Epoch 64 of 87. Elapsed time 5.38 sec
# SLIM_BPR_Recommender: Epoch 65 of 87. Elapsed time 5.47 sec
# SLIM_BPR_Recommender: Epoch 66 of 87. Elapsed time 5.56 sec
# SLIM_BPR_Recommender: Epoch 67 of 87. Elapsed time 5.64 sec
# SLIM_BPR_Recommender: Epoch 68 of 87. Elapsed time 5.74 sec
# SLIM_BPR_Recommender: Epoch 69 of 87. Elapsed time 5.83 sec
# SLIM_BPR_Recommender: Epoch 70 of 87. Elapsed time 5.92 sec
# SLIM_BPR_Recommender: Epoch 71 of 87. Elapsed time 6.01 sec
# SLIM_BPR_Recommender: Epoch 72 of 87. Elapsed time 6.10 sec
# SLIM_BPR_Recommender: Epoch 73 of 87. Elapsed time 6.19 sec
# SLIM_BPR_Recommender: Epoch 74 of 87. Elapsed time 6.28 sec
# SLIM_BPR_Recommender: Epoch 75 of 87. Elapsed time 6.37 sec
# SLIM_BPR_Recommender: Epoch 76 of 87. Elapsed time 6.45 sec
# SLIM_BPR_Recommender: Epoch 77 of 87. Elapsed time 6.54 sec
# SLIM_BPR_Recommender: Epoch 78 of 87. Elapsed time 6.62 sec
# SLIM_BPR_Recommender: Epoch 79 of 87. Elapsed time 6.71 sec
# SLIM_BPR_Recommender: Epoch 80 of 87. Elapsed time 6.79 sec
# SLIM_BPR_Recommender: Epoch 81 of 87. Elapsed time 6.88 sec
# SLIM_BPR_Recommender: Epoch 82 of 87. Elapsed time 6.96 sec
# SLIM_BPR_Recommender: Epoch 83 of 87. Elapsed time 7.04 sec
# SLIM_BPR_Recommender: Epoch 84 of 87. Elapsed time 7.13 sec
# SLIM_BPR_Recommender: Epoch 85 of 87. Elapsed time 7.21 sec
# SLIM_BPR_Recommender: Epoch 86 of 87. Elapsed time 7.30 sec
# SLIM_BPR_Recommender: Epoch 87 of 87. Elapsed time 7.39 sec
# SLIM_BPR_Recommender: Terminating at epoch 87. Elapsed time 36.84 sec
# Deallocating Cython objects

# %%
from KNN.ItemKNNScoresHybridNRecommender import ItemKNNScoresHybridNRecommender
URM_train_ICM_all = sps.vstack([URM_all, ICM_all.T])
#{'alpha': 0.14437291906752261, 'beta': 0.8280826279809712, 'gamma': 0.10013493204432827, 'phi': 0.7790010729326791}
hybrid = ItemKNNScoresHybridNRecommender(URM_train_ICM_all, [recommender_IALS,recommender_rp3Beta,recommender_SLIM,recommender_SLIM_BPR], 4)
hybrid.fit([0.14437291906752261, 0.8280826279809712,  0.10013493204432827,0.7790010729326791])
#evaluator_validation.evaluateRecommender(hybrid)
# Out:
# ItemKNNScoresHybridNRecommender: URM Detected 2 (0.01 %) cold users.
# number of recommenders: 4

# %%
test_users = pd.read_csv('../data_target_users_test.csv')
test_users
# Out:
#       user_id
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
# ...       ...
# 7939     7942
# 7940     7943
# 7941     7944
# 7942     7945
# 7943     7946
#
# [7944 rows x 1 columns]

# %%
user_id = test_users['user_id']
recommendations = hybrid.recommend(user_id,cutoff = 10)

# %%
for index in range(len(recommendations)):
    recommendations[index]=np.array(recommendations[index])
    
print(len(recommendations))

test_users['item_list']= recommendations
test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])

test_users
test_users.to_csv('submission.csv', index=False)
# Out:
# 7944
