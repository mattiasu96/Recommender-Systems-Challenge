# %% [markdown]
# # Data loading
# Next cells are used to load the data we need.

# %%
import pandas as pd
import numpy as np 
import scipy.sparse as sps
import os
import sys
import matplotlib.pyplot as plt

sys.path.append('../..')

from Base.Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from GraphBased.P3alphaRecommender import P3alphaRecommender
from GraphBased.RP3betaRecommender import RP3betaRecommender
from KNN.ItemKNNCBFRecommender import ItemKNNCBFRecommender
from KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender
from KNN.UserKNNCFRecommender import UserKNNCFRecommender
from KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from Base.NonPersonalizedRecommender import TopPop
from MatrixFactorization.PureSVDRecommender import PureSVDRecommender
from SLIM_BPR.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython
from GraphBased.P3alphaRecommender import P3alphaRecommender
from GraphBased.RP3betaRecommender import RP3betaRecommender
from KNN.ItemKNNCBFRecommender import ItemKNNCBFRecommender
from KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender
from KNN.UserKNNCFRecommender import UserKNNCFRecommender
from KNN.ItemKNNScoresHybridMultipleRecommender import ItemKNNScoresHybridMultipleRecommender
from GraphBased.RP3betaRecommender_user import RP3betaRecommender_user
from MatrixFactorization.PureSVDRecommender import PureSVDRecommender
from MatrixFactorization.IALSRecommender import IALSRecommender

# %%
#data which contains users (row), items(col) and implicit interaction (data)
dataset = pd.read_csv('../data_train.csv')
dataset
# Out:
#          row    col  data
# 0          0  10080   1.0
# 1          0  19467   1.0
# 2          1   2665   1.0
# 3          1   7494   1.0
# 4          1  17068   1.0
# ...      ...    ...   ...
# 113263  7945   2476   1.0
# 113264  7945  12319   1.0
# 113265  7945  21384   1.0
# 113266  7946   8699   1.0
# 113267  7946  19178   1.0
#
# [113268 rows x 3 columns]

# %%
unique_users, min_users, max_users = len(dataset.row.unique()), dataset.row.min(), dataset.row.max()
unique_items, min_items, max_items = len(dataset.col.unique()), dataset.col.min(), dataset.col.max()
print('users stats:',unique_users, min_users, max_users)
print('items stats:',unique_items, min_items, max_items)
# Out:
# users stats: 7947 0 7946
# items stats: 24896 0 25974

# %%
users = dataset.row
items = dataset.col
data = dataset.data
URM_all = sps.coo_matrix((data, (users, items)))
URM_all = URM_all.tocsr() #fast row access -> fast access to users 
URM_all.shape
# Out:
# (7947, 25975)

# %%
items_per_user = np.ediff1d(URM_all.indptr) #tells in which position each of the rows begin
users_per_item = np.ediff1d(sps.csc_matrix(URM_all).indptr)
URM_all = sps.csr_matrix(URM_all)

# %%
items_per_user = np.sort(items_per_user) #sorting based on the single value. Losing reference to the user. 
users_per_item = np.sort(users_per_item)

# %%
ICM_df = pd.read_csv('../data_ICM_title_abstract.csv')
ICM_df
# Out:
#           row    col      data
# 0           0   1185  1.015524
# 1           0   2507  0.459024
# 2           0   3534  0.227742
# 3           0   8766  0.501549
# 4           0  10862  0.297011
# ...       ...    ...       ...
# 490686  25974  12554  0.963016
# 490687  25974  13003  0.104613
# 490688  25974  16236  0.118760
# 490689  25974  18797  0.363301
# 490690  25974  19629  0.129141
#
# [490691 rows x 3 columns]

# %%
items = ICM_df.row
features = ICM_df.col
data = ICM_df.data
ICM_all = sps.coo_matrix((data, (items, features)))
ICM_all = ICM_all.tocsr() #fast row access -> fast access to users 
ICM_all.shape
# Out:
# (25975, 20000)

# %%
ICM_all = sps.csr_matrix(ICM_all)
features_per_item = np.ediff1d(ICM_all.indptr)

ICM_all = sps.csc_matrix(ICM_all)
items_per_feature = np.ediff1d(ICM_all.indptr)

ICM_all = sps.csr_matrix(ICM_all)

# %%
features_per_item = np.sort(features_per_item)
items_per_feature = np.sort(items_per_feature)

# %%
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.85)
# Out:
# Warning: 39 (0.49 %) of 7947 users have no train items
# Warning: 3012 (37.90 %) of 7947 users have no sampled items

# %%
grouped_users = dataset.groupby(['row']).count()

# All users present into the dataser
sorted_users = grouped_users.sort_values(by=['col'], ascending=True)
sorted_users = sorted_users.index.to_numpy()
print(len(sorted_users))

'''block_size = int(len(sorted_users)*0.20)

start_pos = 0
end_pos = block_size

users_in_group = sorted_users[start_pos:end_pos]'''


# User for the firt target of users 0-1 interaction
grouped_users = grouped_users[grouped_users['col'] < 2]
users_in_group = grouped_users.sort_values(by=['col'], ascending=True)
users_in_group = users_in_group.index.to_numpy()

user_first_group = users_in_group
# Out:
# 7947

# %%
test_users = pd.read_csv('../data_target_users_test.csv')
test_users
# Out:
#       user_id
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
# ...       ...
# 7939     7942
# 7940     7943
# 7941     7944
# 7942     7945
# 7943     7946
#
# [7944 rows x 1 columns]

# %%
user_id = test_users['user_id'].to_numpy()
user_first_group = user_first_group[np.isin(user_first_group, user_id)]
print(len(user_id))

# 1085 perche sono stati rimossi i 3 utenti di cui non voglio fare reccomend
print(len(user_first_group)) 

users_middle_flag = np.isin(user_id, user_first_group, invert = True)
user_last_group = user_id[users_middle_flag]

print(len(user_first_group))
print(len(user_last_group))
# Out:
# 7944
# 90
# 90
# 7854

# %%
# first 

recommender_alpha = P3alphaRecommender(URM_all)
recommender_alpha.fit(topK=170, alpha = 0.45, implicit = True)

recommender_beta_ICM = RP3betaRecommender(ICM_all.T)
recommender_beta_ICM.fit(topK=70, alpha=0.2, beta=0.5, implicit=False)
recommender_beta_ICM.URM_train = URM_all

evaluator_validation_earlystopping = EvaluatorHoldout(URM_validation, cutoff_list=[10])

earlystopping_keywargs = {"validation_every_n": 5,
                            "stop_on_validation": True,
                            "evaluator_object": evaluator_validation_earlystopping,
                            "lower_validations_allowed": 5,
                            "validation_metric": "MAP" ,
                            }

'''recommender_als = IALSRecommender(URM_train)
recommender_als.fit(epochs = 135,
        num_factors = 153,
        confidence_scaling = "log",
        alpha = 30.61917675327107,
        epsilon = 0.001001609694823079,
        reg = 1.3918031693071822e-05,
        validation_every_n = 5,
        stop_on_validation = True,
        evaluator_object = evaluator_validation_earlystopping,
        lower_validations_allowed = 5,
        validation_metric = "MAP" )'''

hybridrecommender_first_group = ItemKNNSimilarityHybridRecommender(URM_all, recommender_alpha.W_sparse, recommender_beta_ICM.W_sparse)
hybridrecommender_first_group.fit(topK=200, alpha = 0.1)


# second 

recommender_userKNN_top_model = UserKNNCFRecommender(URM_all)
recommender_userKNN_top_model.fit(topK= 75, shrink = 200)

recommender_SVD_top_model = PureSVDRecommender(URM_all)
recommender_SVD_top_model.fit(num_factors = 1200)

recommender_alpha_top_model = P3alphaRecommender(URM_all)
recommender_alpha_top_model.fit(topK=350, alpha = 0.45, implicit = True)

recommender_beta_ICM_top_model = RP3betaRecommender(ICM_all.T)
recommender_beta_ICM_top_model.fit(topK=70, alpha=0.35, beta=0.4, implicit=False)
recommender_beta_ICM_top_model.URM_train = URM_all
# Out:
# P3alphaRecommender: URM Detected 1079 (4.15 %) cold items.
# RP3betaRecommender: URM Detected 2 (0.01 %) cold users.
# RP3betaRecommender: URM Detected 25 (0.10 %) cold items.
# IALSRecommender: URM Detected 39 (0.49 %) cold users.
# IALSRecommender: URM Detected 1983 (7.63 %) cold items.
# IALSRecommender: Epoch 1 of 135. Elapsed time 15.54 sec
# IALSRecommender: Epoch 2 of 135. Elapsed time 31.13 sec
# IALSRecommender: Epoch 3 of 135. Elapsed time 47.13 sec
# IALSRecommender: Epoch 4 of 135. Elapsed time 1.06 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 4935 ( 100.00% ) in 4.81 sec. Users per second: 1027
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1407692, PRECISION: 0.0278825, PRECISION_RECALL_MIN_DEN: 0.1135411, RECALL: 0.1112441, MAP: 0.0504508, MRR: 0.1000286, NDCG: 0.0760842, F1: 0.0445890, HIT_RATE: 0.2788247, ARHR: 0.1118416, NOVELTY: 0.0049285, AVERAGE_POPULARITY: 0.0638079, DIVERSITY_MEAN_INTER_LIST: 0.9959667, DIVERSITY_HERFINDAHL: 0.9995765, COVERAGE_ITEM: 0.4611742, COVERAGE_ITEM_CORRECT: 0.0385756, COVERAGE_USER: 0.6209891, COVERAGE_USER_CORRECT: 0.1371587, DIVERSITY_GINI: 0.1877034, SHANNON_ENTROPY: 12.4007974,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 5 of 135. Elapsed time 1.40 min
# IALSRecommender: Epoch 6 of 135. Elapsed time 1.67 min
# IALSRecommender: Epoch 7 of 135. Elapsed time 1.93 min
# IALSRecommender: Epoch 8 of 135. Elapsed time 2.20 min
# IALSRecommender: Epoch 9 of 135. Elapsed time 2.46 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 4935 ( 100.00% ) in 4.80 sec. Users per second: 1028
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1479303, PRECISION: 0.0299088, PRECISION_RECALL_MIN_DEN: 0.1200601, RECALL: 0.1174812, MAP: 0.0528092, MRR: 0.1042263, NDCG: 0.0799968, F1: 0.0476793, HIT_RATE: 0.2990881, ARHR: 0.1171106, NOVELTY: 0.0050969, AVERAGE_POPULARITY: 0.0576874, DIVERSITY_MEAN_INTER_LIST: 0.9966510, DIVERSITY_HERFINDAHL: 0.9996449, COVERAGE_ITEM: 0.4543215, COVERAGE_ITEM_CORRECT: 0.0404620, COVERAGE_USER: 0.6209891, COVERAGE_USER_CORRECT: 0.1457154, DIVERSITY_GINI: 0.1943515, SHANNON_ENTROPY: 12.5140875,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 10 of 135. Elapsed time 2.81 min
# IALSRecommender: Epoch 11 of 135. Elapsed time 3.08 min
# IALSRecommender: Epoch 12 of 135. Elapsed time 3.35 min
# IALSRecommender: Epoch 13 of 135. Elapsed time 3.61 min
# IALSRecommender: Epoch 14 of 135. Elapsed time 3.88 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 4935 ( 100.00% ) in 4.79 sec. Users per second: 1030
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1480450, PRECISION: 0.0302736, PRECISION_RECALL_MIN_DEN: 0.1202251, RECALL: 0.1176190, MAP: 0.0531116, MRR: 0.1058873, NDCG: 0.0804378, F1: 0.0481531, HIT_RATE: 0.3027356, ARHR: 0.1192225, NOVELTY: 0.0051301, AVERAGE_POPULARITY: 0.0563805, DIVERSITY_MEAN_INTER_LIST: 0.9967652, DIVERSITY_HERFINDAHL: 0.9996563, COVERAGE_ITEM: 0.4471222, COVERAGE_ITEM_CORRECT: 0.0406545, COVERAGE_USER: 0.6209891, COVERAGE_USER_CORRECT: 0.1467220, DIVERSITY_GINI: 0.1932887, SHANNON_ENTROPY: 12.5222376,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 15 of 135. Elapsed time 4.24 min
# IALSRecommender: Epoch 16 of 135. Elapsed time 4.50 min
# IALSRecommender: Epoch 17 of 135. Elapsed time 4.78 min
# IALSRecommender: Epoch 18 of 135. Elapsed time 5.04 min
# IALSRecommender: Epoch 19 of 135. Elapsed time 5.31 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 4935 ( 100.00% ) in 4.80 sec. Users per second: 1029
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1476413, PRECISION: 0.0303951, PRECISION_RECALL_MIN_DEN: 0.1209515, RECALL: 0.1183284, MAP: 0.0531313, MRR: 0.1059237, NDCG: 0.0806027, F1: 0.0483664, HIT_RATE: 0.3039514, ARHR: 0.1193995, NOVELTY: 0.0051415, AVERAGE_POPULARITY: 0.0559375, DIVERSITY_MEAN_INTER_LIST: 0.9967971, DIVERSITY_HERFINDAHL: 0.9996595, COVERAGE_ITEM: 0.4424254, COVERAGE_ITEM_CORRECT: 0.0404235, COVERAGE_USER: 0.6209891, COVERAGE_USER_CORRECT: 0.1477287, DIVERSITY_GINI: 0.1919519, SHANNON_ENTROPY: 12.5197961,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 20 of 135. Elapsed time 5.67 min
# IALSRecommender: Epoch 21 of 135. Elapsed time 5.93 min
# IALSRecommender: Epoch 22 of 135. Elapsed time 6.21 min
# IALSRecommender: Epoch 23 of 135. Elapsed time 6.48 min
# IALSRecommender: Epoch 24 of 135. Elapsed time 6.75 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 4935 ( 100.00% ) in 4.85 sec. Users per second: 1017
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1482687, PRECISION: 0.0303141, PRECISION_RECALL_MIN_DEN: 0.1221648, RECALL: 0.1195451, MAP: 0.0539165, MRR: 0.1067093, NDCG: 0.0813778, F1: 0.0483641, HIT_RATE: 0.3031408, ARHR: 0.1202599, NOVELTY: 0.0051457, AVERAGE_POPULARITY: 0.0560815, DIVERSITY_MEAN_INTER_LIST: 0.9967877, DIVERSITY_HERFINDAHL: 0.9996586, COVERAGE_ITEM: 0.4392300, COVERAGE_ITEM_CORRECT: 0.0405390, COVERAGE_USER: 0.6209891, COVERAGE_USER_CORRECT: 0.1473512, DIVERSITY_GINI: 0.1908895, SHANNON_ENTROPY: 12.5139726,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 25 of 135. Elapsed time 7.10 min
# IALSRecommender: Epoch 26 of 135. Elapsed time 7.37 min
# IALSRecommender: Epoch 27 of 135. Elapsed time 7.64 min
# IALSRecommender: Epoch 28 of 135. Elapsed time 7.91 min
# IALSRecommender: Epoch 29 of 135. Elapsed time 8.19 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 4935 ( 100.00% ) in 4.81 sec. Users per second: 1026
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1484219, PRECISION: 0.0301317, PRECISION_RECALL_MIN_DEN: 0.1214462, RECALL: 0.1188825, MAP: 0.0533990, MRR: 0.1055769, NDCG: 0.0807392, F1: 0.0480777, HIT_RATE: 0.3013171, ARHR: 0.1191034, NOVELTY: 0.0051477, AVERAGE_POPULARITY: 0.0562550, DIVERSITY_MEAN_INTER_LIST: 0.9967773, DIVERSITY_HERFINDAHL: 0.9996575, COVERAGE_ITEM: 0.4388835, COVERAGE_ITEM_CORRECT: 0.0402695, COVERAGE_USER: 0.6209891, COVERAGE_USER_CORRECT: 0.1463445, DIVERSITY_GINI: 0.1907070, SHANNON_ENTROPY: 12.5131243,
#
# IALSRecommender: Epoch 30 of 135. Elapsed time 8.55 min
# IALSRecommender: Epoch 31 of 135. Elapsed time 8.82 min
# IALSRecommender: Epoch 32 of 135. Elapsed time 9.09 min
# IALSRecommender: Epoch 33 of 135. Elapsed time 9.37 min
# IALSRecommender: Epoch 34 of 135. Elapsed time 9.64 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 4935 ( 100.00% ) in 4.83 sec. Users per second: 1022
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1477007, PRECISION: 0.0302330, PRECISION_RECALL_MIN_DEN: 0.1215109, RECALL: 0.1188875, MAP: 0.0530451, MRR: 0.1047723, NDCG: 0.0804609, F1: 0.0482070, HIT_RATE: 0.3023303, ARHR: 0.1181105, NOVELTY: 0.0051486, AVERAGE_POPULARITY: 0.0563160, DIVERSITY_MEAN_INTER_LIST: 0.9967646, DIVERSITY_HERFINDAHL: 0.9996563, COVERAGE_ITEM: 0.4389605, COVERAGE_ITEM_CORRECT: 0.0404235, COVERAGE_USER: 0.6209891, COVERAGE_USER_CORRECT: 0.1467220, DIVERSITY_GINI: 0.1904977, SHANNON_ENTROPY: 12.5109776,
#
# IALSRecommender: Epoch 35 of 135. Elapsed time 9.99 min
# IALSRecommender: Epoch 36 of 135. Elapsed time 10.26 min
# IALSRecommender: Epoch 37 of 135. Elapsed time 10.53 min
# IALSRecommender: Epoch 38 of 135. Elapsed time 10.81 min
# IALSRecommender: Epoch 39 of 135. Elapsed time 11.08 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 4935 ( 100.00% ) in 4.80 sec. Users per second: 1028
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1474732, PRECISION: 0.0301520, PRECISION_RECALL_MIN_DEN: 0.1211952, RECALL: 0.1185692, MAP: 0.0526269, MRR: 0.1038111, NDCG: 0.0799885, F1: 0.0480778, HIT_RATE: 0.3015198, ARHR: 0.1172704, NOVELTY: 0.0051495, AVERAGE_POPULARITY: 0.0563991, DIVERSITY_MEAN_INTER_LIST: 0.9967557, DIVERSITY_HERFINDAHL: 0.9996554, COVERAGE_ITEM: 0.4385371, COVERAGE_ITEM_CORRECT: 0.0401155, COVERAGE_USER: 0.6209891, COVERAGE_USER_CORRECT: 0.1459670, DIVERSITY_GINI: 0.1901868, SHANNON_ENTROPY: 12.5088869,
#
# IALSRecommender: Epoch 40 of 135. Elapsed time 11.43 min
# IALSRecommender: Epoch 41 of 135. Elapsed time 11.70 min
# IALSRecommender: Epoch 42 of 135. Elapsed time 11.98 min
# IALSRecommender: Epoch 43 of 135. Elapsed time 12.25 min
# IALSRecommender: Epoch 44 of 135. Elapsed time 12.52 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 4935 ( 100.00% ) in 4.81 sec. Users per second: 1026
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1472763, PRECISION: 0.0301722, PRECISION_RECALL_MIN_DEN: 0.1217529, RECALL: 0.1191101, MAP: 0.0527776, MRR: 0.1045253, NDCG: 0.0802629, F1: 0.0481479, HIT_RATE: 0.3017224, ARHR: 0.1179488, NOVELTY: 0.0051509, AVERAGE_POPULARITY: 0.0563862, DIVERSITY_MEAN_INTER_LIST: 0.9967499, DIVERSITY_HERFINDAHL: 0.9996548, COVERAGE_ITEM: 0.4376901, COVERAGE_ITEM_CORRECT: 0.0401155, COVERAGE_USER: 0.6209891, COVERAGE_USER_CORRECT: 0.1458412, DIVERSITY_GINI: 0.1899627, SHANNON_ENTROPY: 12.5069888,
#
# IALSRecommender: Epoch 45 of 135. Elapsed time 12.88 min
# IALSRecommender: Epoch 46 of 135. Elapsed time 13.15 min
# IALSRecommender: Epoch 47 of 135. Elapsed time 13.42 min
# IALSRecommender: Epoch 48 of 135. Elapsed time 13.70 min
# IALSRecommender: Epoch 49 of 135. Elapsed time 13.97 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 4935 ( 100.00% ) in 4.83 sec. Users per second: 1022
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1471436, PRECISION: 0.0302330, PRECISION_RECALL_MIN_DEN: 0.1219597, RECALL: 0.1193058, MAP: 0.0526375, MRR: 0.1044850, NDCG: 0.0802216, F1: 0.0482413, HIT_RATE: 0.3023303, ARHR: 0.1178247, NOVELTY: 0.0051511, AVERAGE_POPULARITY: 0.0564255, DIVERSITY_MEAN_INTER_LIST: 0.9967400, DIVERSITY_HERFINDAHL: 0.9996538, COVERAGE_ITEM: 0.4367661, COVERAGE_ITEM_CORRECT: 0.0401540, COVERAGE_USER: 0.6209891, COVERAGE_USER_CORRECT: 0.1463445, DIVERSITY_GINI: 0.1894312, SHANNON_ENTROPY: 12.5035853,
#
# IALSRecommender: Convergence reached! Terminating at epoch 50. Best value for 'MAP' at epoch 25 is 0.0539. Elapsed time 14.33 min
# IALSRecommender: Epoch 50 of 135. Elapsed time 14.33 min
# ItemKNNSimilarityHybridRecommender: URM Detected 1079 (4.15 %) cold items.
# UserKNNCFRecommender: URM Detected 1079 (4.15 %) cold items.
# Similarity column 7947 ( 100 % ), 17412.16 column/sec, elapsed time 0.01 min
# PureSVDRecommender: URM Detected 1079 (4.15 %) cold items.
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# P3alphaRecommender: URM Detected 1079 (4.15 %) cold items.
# RP3betaRecommender: URM Detected 2 (0.01 %) cold users.
# RP3betaRecommender: URM Detected 25 (0.10 %) cold items.

# %%
from KNN.ItemKNNScoresHybridRecommender import ItemKNNScoresHybridRecommender
from KNN.ItemKNNScoresHybridMultipleRecommender import ItemKNNScoresHybridMultipleRecommender

hybridrecommender_p3_rp3_top_model = ItemKNNSimilarityHybridRecommender(URM_all, recommender_alpha_top_model.W_sparse, recommender_beta_ICM_top_model.W_sparse)
hybridrecommender_p3_rp3_top_model.fit(topK=450, alpha = 0.1)

hybridrecommender_top_model = ItemKNNScoresHybridMultipleRecommender(URM_all, hybridrecommender_p3_rp3_top_model, recommender_userKNN_top_model, recommender_SVD_top_model)
hybridrecommender_top_model.fit(alpha = 0.7, beta=0.25)

# make reccomendations for group

recommendations_first = hybridrecommender_first_group.recommend(user_first_group,cutoff = 10)
recommendations_last = hybridrecommender_top_model.recommend(user_last_group,cutoff = 10)
# Out:
# ItemKNNSimilarityHybridRecommender: URM Detected 1079 (4.15 %) cold items.
# ItemKNNScoresHybridMultipleRecommender: URM Detected 1079 (4.15 %) cold items.
# shape of item_weights: (7854, 25975)

# %%
for index in range(len(recommendations_first)):
    recommendations_first[index]=np.array(recommendations_first[index])

print(len(recommendations_first))

for index in range(len(recommendations_last)):
    recommendations_last[index]=np.array(recommendations_last[index])

print(len(recommendations_last))
# Out:
# 90
# 7854

# %%
elementi = test_users['user_id'].to_numpy()
recommendations = []

for index in elementi:
    if index in user_first_group:
        local_index, = np.where(user_first_group == index) 
        recommendations.append(recommendations_first[local_index[0]])
    
    if index in user_last_group:
        local_index, = np.where(user_last_group == index) 
        recommendations.append(recommendations_last[local_index[0]])
    
    print(index, " - ", local_index[0])

print(recommendations)
# Out:
# 50,  4411,  1393,  5337, 21327,
#         9806]), array([18512,  3516, 17674, 12952, 14918,  3831,  2696, 19874, 19970,
#        23404]), array([ 9438, 10269,  6974, 11357, 14253,  4444,  8987, 19220, 25675,
#         9851]), array([22438, 23981,    43,  3759, 25239, 10762,  3631,  4423, 16897,
#         8758]), array([18574,  3037,  1573,  6358, 14684,  3630,  8709, 19303,  4363,
#        11083]), array([ 2426, 10594, 12992,  9322, 19089, 16651, 10792, 23600,  9555,
#        10345]), array([14684, 20308, 19874, 18419,  6500,  2812, 19246,  9526, 20236,
#        14413]), array([12158,  5032, 15903, 21492, 15910, 17724, 18793, 16172, 25342,
#        12048]), array([20308,  4502, 24355,  5581, 24070, 25141,  9034,  8819,  7883,
#        18419]), array([15234,  6544,  2122, 24425,  1722, 19681,  8249, 25918, 20735,
#         7644]), array([24176,  6780,  9544, 15255, 16208, 20973,  9654, 10954,  6152,
#         2002]), array([19089, 19709, 14895, 11730, 19480,  3165, 22914, 17760, 11687,
#        12914]), array([17724, 12158, 13742, 17392, 15642, 15903,  8396, 19263, 10207,
#          893]), array([22715,  8131,  3165, 15402, 15081, 10448,  4871, 11250,  9991,
#         4000]), array([20308, 18419, 10418,  7883, 22653,  5581,  7539, 11737, 19879,
#         6612]), array([25407,  9992, 19468, 16772,  8990, 17195, 21943,  8272, 15691,
#        22594]), array([10496, 11988,  9800, 24491,  4575,  3360, 15798,  3431,  9843,
#        22344]), array([ 5952, 14564, 23086,  3408,  1366, 10625, 18574, 12759, 14939,
#         9370]), array([10792, 10594, 23133, 23001, 25407, 21920,  2426,  9701,  1583,
#         2492]), array([10269, 25675,  5310,  9438, 24679,  9851, 13118, 23799,  6740,
#        12734]), array([24485, 22000, 24328, 25902,  2697,  4779, 18893, 16450, 20586,
#        15650]), array([ 8894, 20988, 11658, 16630,  8431, 18930, 25873,   770, 21491,
#         9664]), array([24865,  2109, 25358, 14038, 16375,  5416,  7589, 21267, 13390,
#        23299]), array([15691, 25407, 25138,  3230, 13711, 10908,  8388, 24069,  9555,
#         1583]), array([18512, 14684, 15484,  3020, 20308, 19780, 13374, 23179,  8395,
#         4502]), array([23481, 17723, 20146, 19089, 19789,  2533, 12119, 17257, 23600,
#        17933]), array([23526, 16664, 20201, 13893, 20829, 16218, 25218, 18537,  4281,
#         1580]), array([ 1863,  8560,  4940,  1947, 22645, 18122, 21552, 13541,  4620,
#         4959]), array([25740, 19398, 23410, 21518,  8691, 24104,   817,  2476,  8158,
#         7313]), array([13231, 13502, 13424,  3456, 12158, 13789, 13182, 17724,  2760,
#        15198]), array([ 9135,  8805, 11702, 17323, 20212, 19007,  4127, 22622, 24199,
#        25766]), array([ 4504,  9167,  1040, 13536,  5036, 13690, 12966, 10972,  4855,
#        23410]), array([23428,  6612, 11114, 13429, 24049, 18892, 24085, 10419,  8705,
#         3155]), array([19874, 14684, 24355, 22653, 18419, 20308, 10418,  4257, 20553,
#         6612]), array([12061,  8544,  9851,   773, 23711, 20148, 10269, 24410, 23666,
#         5717]), array([13661, 15903,  3971,  7690, 12876, 20789, 14796, 18636, 17546,
#        17348]), array([ 2426, 23154, 10594, 25407, 22010, 18392,  9555,  2492, 18452,
#        17156]), array([ 7388, 15372, 21105, 20345,  3871,  3001, 11242, 14564, 21606,
#         1573]), array([ 2001, 20688,  6397, 13226, 23468,  7912, 20161, 17735, 12552,
#        16122]), array([13136,  9733, 11340, 12050,     5, 22801, 18382,  1056, 10690,
#         8309]), array([ 5265, 13928, 14925, 13294,  5784, 14030, 23816, 25675, 14396,
#        15877]), array([23007, 15579, 15988, 15515, 13671, 19726, 12798,  1571,  4224,
#        11449]), array([ 3338, 13855,  9284,  1458, 10099,  1757, 17496, 23110, 20278,
#        19206]), array([13686, 14253, 14316,  4444, 19220,  1211,  3491,  3905,  8987,
#         8367]), array([ 9591,  1863, 25903, 14418, 16552, 18902, 18122,  5751,  6926,
#        24405]), array([ 2304, 25632,  6652, 11700,  8212,   134, 19804, 17637,  5907,
#         9115]), array([ 4359,  2969, 21399, 21597, 12284,  2556, 14175, 19099,  1485,
#        22561]), array([12364,  2274,  1647, 16852,  4845,  2122, 20478,  1722, 12414,
#         3257]), array([23774, 25596,  3580,  5952,  3737,  2118,   358, 13503, 11533,
#        20863]), array([15784, 11900, 11557, 25013, 23080,  9174, 23741, 10903, 16259,
#         4272]), array([10722,  8712,  4787,  6179, 10865, 18495,  7503, 10372, 17288,
#        24663]), array([ 4206, 10187, 20706,  3084, 12332,  2933,  1173, 11089, 13228,
#        21654]), array([ 8544,  1863,   466,  9591, 20148, 20108, 13628,  2619, 24410,
#         4966]), array([15522, 24586,  4552, 17407,  6539, 21112,  1715, 14918,  1898,
#        10685]), array([ 2426, 25407,  9555, 16928, 15691,  9701, 25596, 12818, 10594,
#        23154]), array([16119, 14900, 18630, 18981,  5974, 18952, 19692,  2222,  3138,
#         1555]), array([ 9078, 16779,  8205, 24646, 23415, 10087, 22989,  6372,  6471,
#         6569]), array([20970,  1863, 19049,  5728,  9591,  9050,  4991,  6217,  8069,
#        22226]), array([ 9535, 18045, 21346,  4603, 15113, 11730,   533, 25967,  5294,
#        10665]), array([ 5032,   497, 14674, 18793,  8709, 12048, 13609,  7611, 15182,
#        15559]), array([ 5607,  1583,   883, 24994,  4421, 17299, 13711, 17156, 10594,
#        10834]), array([24484, 10452,  3234, 10446,  2840,  6021,  7479, 17612, 21911,
#        18766]), array([ 5467, 13885, 10865, 24075, 25868, 21498, 17948, 24425, 12808,
#        21317]), array([ 9851,  6610,   561, 24472, 10248,  8379,  1516,  7726,  5543,
#          773]), array([21616, 25526,  8488,  4602,  6502,  3488, 11623,  4115, 19459,
#         3716]), array([ 3497, 24429, 21061,  1846, 16880,  7642,  7550, 13097, 12486,
#         8986]), array([ 9683, 10727, 12591,  7823,  5603,  6450, 10907,  9548,  1345,
#        13097]), array([12742, 18632,   874, 13707,  4691,  8811, 25332,  7235,  5527,
#         3348]), array([18893, 24328, 24485, 24597, 21493, 22473, 13628,  3348, 17927,
#         7338]), array([13764, 16281, 18893, 24328, 20586, 18781,  3114, 17162, 12500,
#         4528]), array([17465, 16214, 13510, 24075, 19113,  2733, 12923, 17877, 13520,
#        16577]), array([12061, 24075, 13867, 25675,  4444, 13686, 11357,  9438, 23711,
#        19220]), array([12983, 20496,   133, 22803, 19120,  1377, 16245, 14454, 22588,
#         4828]), array([ 4502, 14684,  5581, 14137,  4257, 24355, 10418, 20368,  1714,
#        20308]), array([ 9531,  7568,  5150, 17546, 15234,  9511, 15196, 17216, 19287,
#         3971]), array([23898,  1425,   613, 20897, 25481, 25662,  7007, 23115,   839,
#         1377]), array([25407,  1583, 23154, 10908,  5607, 10594, 15691,  2426,  9322,
#        17877]), array([ 3456, 13789, 14485, 13424, 17423,  5905,  8558, 24655,  6864,
#        10489]), array([ 2646,   273, 15477,  6213, 16551, 16974,  6123,  4919,  5612,
#        13138]), array([ 7696,  9421, 23799,  6718, 21254,  1384, 14633, 14062, 17668,
#        15237]), array([ 8373, 14513, 16040,  3810,  2810, 20950, 21751,  4570, 18185,
#          265]), array([ 9555,  1583, 10834, 16928,  6734, 16906, 22848, 23141,  7991,
#        17156]), array([22998, 22308,  2554, 18169,  3145,  8591,  4724, 24672,  6967,
#         3566]), array([  194, 24423, 12844,  7115, 15674,  5966, 14704, 20416,  4370,
#        18709]), array([  942,  1516, 24795, 14483, 16949, 12061, 10248, 21883, 20934,
#         1830]), array([ 1985, 25030,  7808,   379, 21859,   684,  5746, 14311, 25491,
#         6767]), array([23895, 23086, 10311, 12165, 20508, 11527,  1005,  4909, 11003,
#        10472]), array([ 1898,  6264,  5626, 17407, 16968, 15522, 15213, 19691, 10685,
#         6520]), array([20148, 21552,  8920, 23536,  4528, 11452,  2049, 18114,  3469,
#        14023]), array([10269, 25675, 11792,  3835, 23589, 12272, 10859, 18259,  2300,
#        13213]), array([25645, 16100, 13207, 23280,  7708,  8667, 22478,  4384,  2716,
#        16688]), array([18790, 22807,  6264, 15903,  8902,  6520,  3432,  6539,  7689,
#         6088]), array([17209, 15691,     5,  6327,  9733, 11340, 12050, 10594, 23154,
#        10834]), array([ 2516,  5165, 17844, 22727, 24127, 10189, 12448, 25260, 11938,
#         6815]), array([ 2835,  6442, 10066, 22282, 11946,  3576, 20308,  6212, 15636,
#         9701]), array([ 5998, 25191,  3025, 23977,  2154, 12340,  3935,  5833, 21266,
#        21830]), array([ 9941,  5945, 15736,  7494,  7805, 22979, 12061,  6500, 14918,
#         7919]), array([13764, 24597,  2751, 22473,  9732,  4779, 18893, 10979, 14593,
#        24328]), array([23238,  3912, 20235, 22615,  9601,  5466,  7043, 21480,   780,
#          958]), array([18190, 23536, 13541,  2333, 12341, 15327, 23711,  2300,   454,
#        24756]), array([ 9591,  3368, 21132, 15014, 24405,  6754, 25755,  4095, 13541,
#        25903]), array([ 1039, 20308, 20706, 24481, 15484, 14684, 13090,  2933, 24197,
#        20733]), array([ 9241, 12158, 17724, 10213, 14156,  7662,  8396, 24388,  9986,
#         7981]), array([17390, 17133, 12836,  4985, 20093, 14295, 11214, 24040, 25073,
#         8387]), array([14418, 11792,  9050, 21890,  4966, 23671, 11360, 25903,  6894,
#        17916]), array([14012, 19704, 13427,  6108,  9582, 21537,  1526, 19450,  9243,
#        18380]), array([13408,  3835, 24721, 17788,  6030, 20560,  9547, 18296, 11797,
#        15416]), array([ 7530, 14329, 16513, 16858, 14351,  9349, 21208, 25340, 11400,
#        19166]), array([12743, 22333, 10045, 24075,   275,  5119,  9435, 10269, 16661,
#        21336]), array([ 3497, 14141,  1869,   502,  5469, 12486, 21061,  1846, 19769,
#         7384]), array([17229,   195,  3743,  8990, 20969, 22840, 19236, 19468, 24959,
#        10373]), array([ 9435, 12158,  4766, 10396, 19480, 16569,  8275, 14838, 21302,
#         7260]), array([13493, 18057,  3631, 22438, 17680, 23255,  3392, 17561, 15394,
#           43]), array([13927, 17090, 25928, 23960,  9753, 22754, 24349,  7335, 13417,
#         2196]), array([25524, 18293, 24474, 15678,  4855,  1904, 22750, 22928, 22710,
#        22712]), array([ 9733, 17209, 13136,  8309,  8677, 13902, 16775,  9661,  5199,
#        10675]), array([11467,  1468, 22968, 18825, 10328, 21510, 19124,  4768, 24200,
#        15903]), array([ 5129, 11298,  2919, 20304, 15497, 25815, 19717,  8534, 15087,
#         6369]), array([ 9907,  9567,  4291, 14139,   829, 21192, 24832, 10959, 16823,
#        21844]), array([13541, 23536, 11792, 22356, 18528, 10450, 13030,  9337, 15459,
#        23457]), array([ 8709, 20300,  7267,  5025,  9769,  9662,  9716, 22548, 13609,
#        15182]), array([24398, 25338, 24764,  2458, 24411,  4068, 11445, 10212, 20130,
#        15014]), array([19874, 16394, 20368,  5557, 21180, 25349, 14137, 25760, 11033,
#        16327]), array([ 8691,  1651, 13690, 22487, 12110, 12348, 20990, 13875,  2562,
#         1405]), array([19480, 25740,  7313, 23410, 19524, 19398, 19010, 15709, 16471,
#         3513]), array([ 2838, 18054, 16522,  2523, 18227, 14904,  6828, 18129, 10752,
#         8316])]

# %%
test_users['item_list']= recommendations

test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])

test_users
test_users.to_csv('submission.csv', index=False)
