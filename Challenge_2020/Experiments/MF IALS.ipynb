# %%
import pandas as pd
import numpy as np 
import scipy.sparse as sps
import os
import sys
import matplotlib.pyplot as plt
sys.path.append('../..')

# %%
#data which contains users (row), items(col) and implicit interaction (data)
dataset = pd.read_csv('../data_train.csv')
dataset
# Out:
#          row    col  data
# 0          0  10080   1.0
# 1          0  19467   1.0
# 2          1   2665   1.0
# 3          1   7494   1.0
# 4          1  17068   1.0
# ...      ...    ...   ...
# 113263  7945   2476   1.0
# 113264  7945  12319   1.0
# 113265  7945  21384   1.0
# 113266  7946   8699   1.0
# 113267  7946  19178   1.0
#
# [113268 rows x 3 columns]

# %%
users = dataset.row
items = dataset.col
data = dataset.data
URM_all = sps.coo_matrix((data, (users, items)))
URM_all = URM_all.tocsr() #fast row access -> fast access to users 
URM_all.shape
# Out:
# (7947, 25975)

# %%
ICM_df = pd.read_csv('../data_ICM_title_abstract.csv')
ICM_df
# Out:
#           row    col      data
# 0           0   1185  1.015524
# 1           0   2507  0.459024
# 2           0   3534  0.227742
# 3           0   8766  0.501549
# 4           0  10862  0.297011
# ...       ...    ...       ...
# 490686  25974  12554  0.963016
# 490687  25974  13003  0.104613
# 490688  25974  16236  0.118760
# 490689  25974  18797  0.363301
# 490690  25974  19629  0.129141
#
# [490691 rows x 3 columns]

# %%
items = ICM_df.row
features = ICM_df.col
data = ICM_df.data
ICM_all = sps.coo_matrix((data, (items, features)))
ICM_all = ICM_all.tocsr() #fast row access -> fast access to users 
ICM_all.shape
# Out:
# (25975, 20000)

# %%
from Base.Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.85)
# Out:
# Warning: 36 (0.45 %) of 7947 users have no train items
# Warning: 2931 (36.88 %) of 7947 users have no sampled items

# %%
evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])

# %%
from skopt.space import Real, Integer, Categorical
from MatrixFactorization.IALSRecommender import IALSRecommender
from ParameterTuning.SearchAbstractClass import SearchInputRecommenderArgs
from ParameterTuning.SearchBayesianSkopt import SearchBayesianSkopt

hyperparameters_range_dictionary = {}
hyperparameters_range_dictionary["num_factors"] = Integer(1, 200)
hyperparameters_range_dictionary["confidence_scaling"] = Categorical(["linear", "log"])
hyperparameters_range_dictionary["alpha"] = Real(low = 1e-3, high = 50.0, prior = 'log-uniform')
hyperparameters_range_dictionary["epsilon"] = Real(low = 1e-3, high = 10.0, prior = 'log-uniform')
hyperparameters_range_dictionary["reg"] = Real(low = 1e-5, high = 1e-2, prior = 'log-uniform')

grouped_users = dataset.groupby(['row']).count()

# All users present into the dataser
sorted_users = grouped_users.sort_values(by=['col'], ascending=True)
sorted_users = sorted_users.index.to_numpy()
print(len(sorted_users))

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])

recommender_class = IALSRecommender

parameterSearch = SearchBayesianSkopt(recommender_class,
                                 evaluator_validation=evaluator_validation,
                                 evaluator_test=evaluator_validation)

import os

output_folder_path = "result_experiments/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 10
n_random_starts = int(n_cases*0.3)

metric_to_optimize = "MAP" 
evaluator_validation_earlystopping = EvaluatorHoldout(URM_validation, cutoff_list=[10])

earlystopping_keywargs = {"validation_every_n": 5,
                              "stop_on_validation": True,
                              "evaluator_object": evaluator_validation_earlystopping,
                              "lower_validations_allowed": 5,
                              "validation_metric": metric_to_optimize,
                              }

recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = earlystopping_keywargs
)

recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_all],
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = earlystopping_keywargs
)


parameterSearch.search(recommender_input_args,
                       recommender_input_args_last_test = recommender_input_args_last_test,
                       parameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path,
                       output_file_name_root = recommender_class.RECOMMENDER_NAME,
                       metric_to_optimize = metric_to_optimize,
                      )

from Base.DataIO import DataIO

data_loader = DataIO(folder_path = output_folder_path)

search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")

hyperparameters_list = search_metadata["hyperparameters_list"]

best_parameters = search_metadata["hyperparameters_best"]
best_parameters
# Out:
# ER_CORRECT: 0.1460929, DIVERSITY_GINI: 0.1904250, SHANNON_ENTROPY: 12.5035463,
#
# IALSRecommender: Epoch 115 of 300. Elapsed time 39.08 min
# IALSRecommender: Epoch 116 of 300. Elapsed time 39.40 min
# IALSRecommender: Epoch 117 of 300. Elapsed time 39.72 min
# IALSRecommender: Epoch 118 of 300. Elapsed time 40.04 min
# IALSRecommender: Epoch 119 of 300. Elapsed time 40.36 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.58 sec. Users per second: 1094
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1476563, PRECISION: 0.0295056, PRECISION_RECALL_MIN_DEN: 0.1167451, RECALL: 0.1142392, MAP: 0.0527017, MRR: 0.1068685, NDCG: 0.0798151, F1: 0.0468983, HIT_RATE: 0.2950558, ARHR: 0.1195615, NOVELTY: 0.0051512, AVERAGE_POPULARITY: 0.0567749, DIVERSITY_MEAN_INTER_LIST: 0.9966796, DIVERSITY_HERFINDAHL: 0.9996481, COVERAGE_ITEM: 0.4393455, COVERAGE_ITEM_CORRECT: 0.0400770, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.1459670, DIVERSITY_GINI: 0.1903146, SHANNON_ENTROPY: 12.5021660,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 120 of 300. Elapsed time 40.76 min
# IALSRecommender: Epoch 121 of 300. Elapsed time 41.08 min
# IALSRecommender: Epoch 122 of 300. Elapsed time 41.40 min
# IALSRecommender: Epoch 123 of 300. Elapsed time 41.73 min
# IALSRecommender: Epoch 124 of 300. Elapsed time 42.05 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.58 sec. Users per second: 1094
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1477983, PRECISION: 0.0296053, PRECISION_RECALL_MIN_DEN: 0.1169267, RECALL: 0.1143924, MAP: 0.0529119, MRR: 0.1076128, NDCG: 0.0801051, F1: 0.0470371, HIT_RATE: 0.2960526, ARHR: 0.1203098, NOVELTY: 0.0051515, AVERAGE_POPULARITY: 0.0567164, DIVERSITY_MEAN_INTER_LIST: 0.9966827, DIVERSITY_HERFINDAHL: 0.9996484, COVERAGE_ITEM: 0.4395380, COVERAGE_ITEM_CORRECT: 0.0401925, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.1464704, DIVERSITY_GINI: 0.1903589, SHANNON_ENTROPY: 12.5025862,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 125 of 300. Elapsed time 42.45 min
# IALSRecommender: Epoch 126 of 300. Elapsed time 42.77 min
# IALSRecommender: Epoch 127 of 300. Elapsed time 43.09 min
# IALSRecommender: Epoch 128 of 300. Elapsed time 43.41 min
# IALSRecommender: Epoch 129 of 300. Elapsed time 43.73 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.59 sec. Users per second: 1093
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1477096, PRECISION: 0.0294258, PRECISION_RECALL_MIN_DEN: 0.1167584, RECALL: 0.1142281, MAP: 0.0528082, MRR: 0.1074703, NDCG: 0.0799275, F1: 0.0467966, HIT_RATE: 0.2942584, ARHR: 0.1200534, NOVELTY: 0.0051512, AVERAGE_POPULARITY: 0.0568134, DIVERSITY_MEAN_INTER_LIST: 0.9966746, DIVERSITY_HERFINDAHL: 0.9996476, COVERAGE_ITEM: 0.4398075, COVERAGE_ITEM_CORRECT: 0.0398460, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.1458412, DIVERSITY_GINI: 0.1904058, SHANNON_ENTROPY: 12.5020385,
#
# IALSRecommender: Epoch 130 of 300. Elapsed time 44.13 min
# IALSRecommender: Epoch 131 of 300. Elapsed time 44.45 min
# IALSRecommender: Epoch 132 of 300. Elapsed time 44.77 min
# IALSRecommender: Epoch 133 of 300. Elapsed time 45.09 min
# IALSRecommender: Epoch 134 of 300. Elapsed time 45.42 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.59 sec. Users per second: 1094
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1475070, PRECISION: 0.0296451, PRECISION_RECALL_MIN_DEN: 0.1177515, RECALL: 0.1152329, MAP: 0.0529239, MRR: 0.1076617, NDCG: 0.0802648, F1: 0.0471582, HIT_RATE: 0.2964514, ARHR: 0.1203800, NOVELTY: 0.0051510, AVERAGE_POPULARITY: 0.0568594, DIVERSITY_MEAN_INTER_LIST: 0.9966694, DIVERSITY_HERFINDAHL: 0.9996471, COVERAGE_ITEM: 0.4394995, COVERAGE_ITEM_CORRECT: 0.0401540, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.1464704, DIVERSITY_GINI: 0.1902016, SHANNON_ENTROPY: 12.5006187,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 135 of 300. Elapsed time 45.82 min
# IALSRecommender: Epoch 136 of 300. Elapsed time 46.14 min
# IALSRecommender: Epoch 137 of 300. Elapsed time 46.46 min
# IALSRecommender: Epoch 138 of 300. Elapsed time 46.78 min
# IALSRecommender: Epoch 139 of 300. Elapsed time 47.10 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.59 sec. Users per second: 1092
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1477925, PRECISION: 0.0296053, PRECISION_RECALL_MIN_DEN: 0.1177897, RECALL: 0.1152626, MAP: 0.0527540, MRR: 0.1073080, NDCG: 0.0801133, F1: 0.0471102, HIT_RATE: 0.2960526, ARHR: 0.1199162, NOVELTY: 0.0051512, AVERAGE_POPULARITY: 0.0568965, DIVERSITY_MEAN_INTER_LIST: 0.9966680, DIVERSITY_HERFINDAHL: 0.9996469, COVERAGE_ITEM: 0.4395765, COVERAGE_ITEM_CORRECT: 0.0400770, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.1468479, DIVERSITY_GINI: 0.1902746, SHANNON_ENTROPY: 12.5008637,
#
# IALSRecommender: Epoch 140 of 300. Elapsed time 47.50 min
# IALSRecommender: Epoch 141 of 300. Elapsed time 47.82 min
# IALSRecommender: Epoch 142 of 300. Elapsed time 48.14 min
# IALSRecommender: Epoch 143 of 300. Elapsed time 48.46 min
# IALSRecommender: Epoch 144 of 300. Elapsed time 48.79 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.62 sec. Users per second: 1087
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1479886, PRECISION: 0.0295654, PRECISION_RECALL_MIN_DEN: 0.1176103, RECALL: 0.1150814, MAP: 0.0528392, MRR: 0.1074099, NDCG: 0.0801379, F1: 0.0470446, HIT_RATE: 0.2956539, ARHR: 0.1199714, NOVELTY: 0.0051516, AVERAGE_POPULARITY: 0.0569130, DIVERSITY_MEAN_INTER_LIST: 0.9966685, DIVERSITY_HERFINDAHL: 0.9996470, COVERAGE_ITEM: 0.4394225, COVERAGE_ITEM_CORRECT: 0.0400000, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.1465962, DIVERSITY_GINI: 0.1901971, SHANNON_ENTROPY: 12.5005980,
#
# IALSRecommender: Epoch 145 of 300. Elapsed time 49.18 min
# IALSRecommender: Epoch 146 of 300. Elapsed time 49.50 min
# IALSRecommender: Epoch 147 of 300. Elapsed time 49.82 min
# IALSRecommender: Epoch 148 of 300. Elapsed time 50.14 min
# IALSRecommender: Epoch 149 of 300. Elapsed time 50.46 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.58 sec. Users per second: 1095
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1478029, PRECISION: 0.0296651, PRECISION_RECALL_MIN_DEN: 0.1182560, RECALL: 0.1157256, MAP: 0.0528721, MRR: 0.1072734, NDCG: 0.0802950, F1: 0.0472246, HIT_RATE: 0.2966507, ARHR: 0.1198504, NOVELTY: 0.0051513, AVERAGE_POPULARITY: 0.0569571, DIVERSITY_MEAN_INTER_LIST: 0.9966635, DIVERSITY_HERFINDAHL: 0.9996465, COVERAGE_ITEM: 0.4393070, COVERAGE_ITEM_CORRECT: 0.0401155, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.1472254, DIVERSITY_GINI: 0.1901310, SHANNON_ENTROPY: 12.4998150,
#
# IALSRecommender: Epoch 150 of 300. Elapsed time 50.86 min
# IALSRecommender: Epoch 151 of 300. Elapsed time 51.18 min
# IALSRecommender: Epoch 152 of 300. Elapsed time 51.50 min
# IALSRecommender: Epoch 153 of 300. Elapsed time 51.82 min
# IALSRecommender: Epoch 154 of 300. Elapsed time 52.14 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.60 sec. Users per second: 1091
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1476505, PRECISION: 0.0296850, PRECISION_RECALL_MIN_DEN: 0.1188253, RECALL: 0.1162896, MAP: 0.0526905, MRR: 0.1068656, NDCG: 0.0802472, F1: 0.0472967, HIT_RATE: 0.2968501, ARHR: 0.1192693, NOVELTY: 0.0051512, AVERAGE_POPULARITY: 0.0569929, DIVERSITY_MEAN_INTER_LIST: 0.9966604, DIVERSITY_HERFINDAHL: 0.9996462, COVERAGE_ITEM: 0.4394610, COVERAGE_ITEM_CORRECT: 0.0400770, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.1478545, DIVERSITY_GINI: 0.1901112, SHANNON_ENTROPY: 12.4996003,
#
# IALSRecommender: Epoch 155 of 300. Elapsed time 52.54 min
# IALSRecommender: Epoch 156 of 300. Elapsed time 52.86 min
# IALSRecommender: Epoch 157 of 300. Elapsed time 53.18 min
# IALSRecommender: Epoch 158 of 300. Elapsed time 53.50 min
# IALSRecommender: Epoch 159 of 300. Elapsed time 53.83 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.62 sec. Users per second: 1086
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1473188, PRECISION: 0.0296850, PRECISION_RECALL_MIN_DEN: 0.1189250, RECALL: 0.1163848, MAP: 0.0526949, MRR: 0.1067429, NDCG: 0.0802349, F1: 0.0473046, HIT_RATE: 0.2968501, ARHR: 0.1191983, NOVELTY: 0.0051509, AVERAGE_POPULARITY: 0.0570833, DIVERSITY_MEAN_INTER_LIST: 0.9966547, DIVERSITY_HERFINDAHL: 0.9996456, COVERAGE_ITEM: 0.4395765, COVERAGE_ITEM_CORRECT: 0.0400385, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.1477287, DIVERSITY_GINI: 0.1900871, SHANNON_ENTROPY: 12.4990965,
#
# IALSRecommender: Convergence reached! Terminating at epoch 160. Best value for 'MAP' at epoch 135 is 0.0529. Elapsed time 54.22 min
# IALSRecommender: Epoch 160 of 300. Elapsed time 54.22 min
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.60 sec. Users per second: 1091
# SearchBayesianSkopt: New best config found. Config 9: {'num_factors': 153, 'confidence_scaling': 'log', 'alpha': 30.61917675327107, 'epsilon': 0.001001609694823079, 'reg': 1.3918031693071822e-05, 'epochs': 135} - results: ROC_AUC: 0.1475070, PRECISION: 0.0296451, PRECISION_RECALL_MIN_DEN: 0.1177515, RECALL: 0.1152329, MAP: 0.0529239, MRR: 0.1076617, NDCG: 0.0802648, F1: 0.0471582, HIT_RATE: 0.2964514, ARHR: 0.1203800, NOVELTY: 0.0051510, AVERAGE_POPULARITY: 0.0568594, DIVERSITY_MEAN_INTER_LIST: 0.9966694, DIVERSITY_HERFINDAHL: 0.9996471, COVERAGE_ITEM: 0.4394995, COVERAGE_ITEM_CORRECT: 0.0401540, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.1464704, DIVERSITY_GINI: 0.1902016, SHANNON_ENTROPY: 12.5006187,
#
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.58 sec. Users per second: 1095
# SearchBayesianSkopt: Best config evaluated with evaluator_test. Config: {'num_factors': 153, 'confidence_scaling': 'log', 'alpha': 30.61917675327107, 'epsilon': 0.001001609694823079, 'reg': 1.3918031693071822e-05, 'epochs': 135} - results:
# CUTOFF: 10 - ROC_AUC: 0.1475070, PRECISION: 0.0296451, PRECISION_RECALL_MIN_DEN: 0.1177515, RECALL: 0.1152329, MAP: 0.0529239, MRR: 0.1076617, NDCG: 0.0802648, F1: 0.0471582, HIT_RATE: 0.2964514, ARHR: 0.1203800, NOVELTY: 0.0051510, AVERAGE_POPULARITY: 0.0568594, DIVERSITY_MEAN_INTER_LIST: 0.9966694, DIVERSITY_HERFINDAHL: 0.9996471, COVERAGE_ITEM: 0.4394995, COVERAGE_ITEM_CORRECT: 0.0401540, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.1464704, DIVERSITY_GINI: 0.1902016, SHANNON_ENTROPY: 12.5006187,
#
#
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 3263.0036
# Function value obtained: -0.0529
# Current minimum: -0.0529
# SearchBayesianSkopt: Search complete. Best config is 9: {'num_factors': 153, 'confidence_scaling': 'log', 'alpha': 30.61917675327107, 'epsilon': 0.001001609694823079, 'reg': 1.3918031693071822e-05, 'epochs': 135}
#
# IALSRecommender: URM Detected 1079 (4.15 %) cold items.
# SearchBayesianSkopt: Evaluation with constructor data for final test. Using best config: {'num_factors': 153, 'confidence_scaling': 'log', 'alpha': 30.61917675327107, 'epsilon': 0.001001609694823079, 'reg': 1.3918031693071822e-05, 'epochs': 135}
# IALSRecommender: Epoch 1 of 135. Elapsed time 19.94 sec
# IALSRecommender: Epoch 2 of 135. Elapsed time 39.77 sec
# IALSRecommender: Epoch 3 of 135. Elapsed time 1.00 min
# IALSRecommender: Epoch 4 of 135. Elapsed time 1.34 min
# IALSRecommender: Epoch 5 of 135. Elapsed time 1.67 min
# IALSRecommender: Epoch 6 of 135. Elapsed time 2.00 min
# IALSRecommender: Epoch 7 of 135. Elapsed time 2.33 min
# IALSRecommender: Epoch 8 of 135. Elapsed time 2.67 min
# IALSRecommender: Epoch 9 of 135. Elapsed time 3.00 min
# IALSRecommender: Epoch 10 of 135. Elapsed time 3.33 min
# IALSRecommender: Epoch 11 of 135. Elapsed time 3.66 min
# IALSRecommender: Epoch 12 of 135. Elapsed time 3.99 min
# IALSRecommender: Epoch 13 of 135. Elapsed time 4.33 min
# IALSRecommender: Epoch 14 of 135. Elapsed time 4.66 min
# IALSRecommender: Epoch 15 of 135. Elapsed time 4.99 min
# IALSRecommender: Epoch 16 of 135. Elapsed time 5.32 min
# IALSRecommender: Epoch 17 of 135. Elapsed time 5.65 min
# IALSRecommender: Epoch 18 of 135. Elapsed time 5.99 min
# IALSRecommender: Epoch 19 of 135. Elapsed time 6.32 min
# IALSRecommender: Epoch 20 of 135. Elapsed time 6.65 min
# IALSRecommender: Epoch 21 of 135. Elapsed time 6.98 min
# IALSRecommender: Epoch 22 of 135. Elapsed time 7.31 min
# IALSRecommender: Epoch 23 of 135. Elapsed time 7.65 min
# IALSRecommender: Epoch 24 of 135. Elapsed time 7.98 min
# IALSRecommender: Epoch 25 of 135. Elapsed time 8.31 min
# IALSRecommender: Epoch 26 of 135. Elapsed time 8.64 min
# IALSRecommender: Epoch 27 of 135. Elapsed time 8.97 min
# IALSRecommender: Epoch 28 of 135. Elapsed time 9.30 min
# IALSRecommender: Epoch 29 of 135. Elapsed time 9.63 min
# IALSRecommender: Epoch 30 of 135. Elapsed time 9.97 min
# IALSRecommender: Epoch 31 of 135. Elapsed time 10.30 min
# IALSRecommender: Epoch 32 of 135. Elapsed time 10.63 min
# IALSRecommender: Epoch 33 of 135. Elapsed time 10.96 min
# IALSRecommender: Epoch 34 of 135. Elapsed time 11.30 min
# IALSRecommender: Epoch 35 of 135. Elapsed time 11.63 min
# IALSRecommender: Epoch 36 of 135. Elapsed time 11.96 min
# IALSRecommender: Epoch 37 of 135. Elapsed time 12.30 min
# IALSRecommender: Epoch 38 of 135. Elapsed time 12.63 min
# IALSRecommender: Epoch 39 of 135. Elapsed time 12.96 min
# IALSRecommender: Epoch 40 of 135. Elapsed time 13.30 min
# IALSRecommender: Epoch 41 of 135. Elapsed time 13.63 min
# IALSRecommender: Epoch 42 of 135. Elapsed time 13.97 min
# IALSRecommender: Epoch 43 of 135. Elapsed time 14.30 min
# IALSRecommender: Epoch 44 of 135. Elapsed time 14.64 min
# IALSRecommender: Epoch 45 of 135. Elapsed time 14.97 min
# IALSRecommender: Epoch 46 of 135. Elapsed time 15.30 min
# IALSRecommender: Epoch 47 of 135. Elapsed time 15.63 min
# IALSRecommender: Epoch 48 of 135. Elapsed time 15.97 min
# IALSRecommender: Epoch 49 of 135. Elapsed time 16.30 min
# IALSRecommender: Epoch 50 of 135. Elapsed time 16.63 min
# IALSRecommender: Epoch 51 of 135. Elapsed time 16.96 min
# IALSRecommender: Epoch 52 of 135. Elapsed time 17.30 min
# IALSRecommender: Epoch 53 of 135. Elapsed time 17.63 min
# IALSRecommender: Epoch 54 of 135. Elapsed time 17.96 min
# IALSRecommender: Epoch 55 of 135. Elapsed time 18.29 min
# IALSRecommender: Epoch 56 of 135. Elapsed time 18.62 min
# IALSRecommender: Epoch 57 of 135. Elapsed time 18.96 min
# IALSRecommender: Epoch 58 of 135. Elapsed time 19.30 min
# IALSRecommender: Epoch 59 of 135. Elapsed time 19.64 min
# IALSRecommender: Epoch 60 of 135. Elapsed time 19.97 min
# IALSRecommender: Epoch 61 of 135. Elapsed time 20.30 min
# IALSRecommender: Epoch 62 of 135. Elapsed time 20.64 min
# IALSRecommender: Epoch 63 of 135. Elapsed time 20.97 min
# IALSRecommender: Epoch 64 of 135. Elapsed time 21.31 min
# IALSRecommender: Epoch 65 of 135. Elapsed time 21.64 min
# IALSRecommender: Epoch 66 of 135. Elapsed time 21.98 min
# IALSRecommender: Epoch 67 of 135. Elapsed time 22.31 min
# IALSRecommender: Epoch 68 of 135. Elapsed time 52.28 min
# IALSRecommender: Epoch 69 of 135. Elapsed time 1.56 hour
# IALSRecommender: Epoch 70 of 135. Elapsed time 3.57 hour
# IALSRecommender: Epoch 71 of 135. Elapsed time 4.72 hour
# IALSRecommender: Epoch 72 of 135. Elapsed time 5.78 hour
# IALSRecommender: Epoch 73 of 135. Elapsed time 5.80 hour
# IALSRecommender: Epoch 74 of 135. Elapsed time 5.99 hour
# IALSRecommender: Epoch 75 of 135. Elapsed time 6.01 hour
# IALSRecommender: Epoch 76 of 135. Elapsed time 6.02 hour
# IALSRecommender: Epoch 77 of 135. Elapsed time 7.24 hour
# IALSRecommender: Epoch 78 of 135. Elapsed time 7.26 hour
# IALSRecommender: Epoch 79 of 135. Elapsed time 7.27 hour
# IALSRecommender: Epoch 80 of 135. Elapsed time 7.29 hour
# IALSRecommender: Epoch 81 of 135. Elapsed time 7.30 hour
# IALSRecommender: Epoch 82 of 135. Elapsed time 7.31 hour
# IALSRecommender: Epoch 83 of 135. Elapsed time 7.33 hour
# IALSRecommender: Epoch 84 of 135. Elapsed time 7.34 hour
# IALSRecommender: Epoch 85 of 135. Elapsed time 7.36 hour
# IALSRecommender: Epoch 86 of 135. Elapsed time 7.37 hour
# IALSRecommender: Epoch 87 of 135. Elapsed time 7.39 hour
# IALSRecommender: Epoch 88 of 135. Elapsed time 7.40 hour
# IALSRecommender: Epoch 89 of 135. Elapsed time 7.41 hour
# IALSRecommender: Epoch 90 of 135. Elapsed time 7.43 hour
# IALSRecommender: Epoch 91 of 135. Elapsed time 7.44 hour
# IALSRecommender: Epoch 92 of 135. Elapsed time 7.46 hour
# IALSRecommender: Epoch 93 of 135. Elapsed time 7.47 hour
# IALSRecommender: Epoch 94 of 135. Elapsed time 7.49 hour
# IALSRecommender: Epoch 95 of 135. Elapsed time 7.50 hour
# IALSRecommender: Epoch 96 of 135. Elapsed time 7.52 hour
# IALSRecommender: Epoch 97 of 135. Elapsed time 7.53 hour
# IALSRecommender: Epoch 98 of 135. Elapsed time 7.55 hour
# IALSRecommender: Epoch 99 of 135. Elapsed time 7.56 hour
# IALSRecommender: Epoch 100 of 135. Elapsed time 7.58 hour
# IALSRecommender: Epoch 101 of 135. Elapsed time 7.59 hour
# IALSRecommender: Epoch 102 of 135. Elapsed time 7.60 hour
# IALSRecommender: Epoch 103 of 135. Elapsed time 7.62 hour
# IALSRecommender: Epoch 104 of 135. Elapsed time 7.63 hour
# IALSRecommender: Epoch 105 of 135. Elapsed time 7.65 hour
# IALSRecommender: Epoch 106 of 135. Elapsed time 7.66 hour
# IALSRecommender: Epoch 107 of 135. Elapsed time 7.67 hour
# IALSRecommender: Epoch 108 of 135. Elapsed time 7.68 hour
# IALSRecommender: Epoch 109 of 135. Elapsed time 7.68 hour
# IALSRecommender: Epoch 110 of 135. Elapsed time 7.69 hour
# IALSRecommender: Epoch 111 of 135. Elapsed time 7.69 hour
# IALSRecommender: Epoch 112 of 135. Elapsed time 7.70 hour
# IALSRecommender: Epoch 113 of 135. Elapsed time 7.70 hour
# IALSRecommender: Epoch 114 of 135. Elapsed time 7.71 hour
# IALSRecommender: Epoch 115 of 135. Elapsed time 7.71 hour
# IALSRecommender: Epoch 116 of 135. Elapsed time 7.72 hour
# IALSRecommender: Epoch 117 of 135. Elapsed time 7.73 hour
# IALSRecommender: Epoch 118 of 135. Elapsed time 7.73 hour
# IALSRecommender: Epoch 119 of 135. Elapsed time 7.74 hour
# IALSRecommender: Epoch 120 of 135. Elapsed time 7.74 hour
# IALSRecommender: Epoch 121 of 135. Elapsed time 7.75 hour
# IALSRecommender: Epoch 122 of 135. Elapsed time 7.75 hour
# IALSRecommender: Epoch 123 of 135. Elapsed time 7.76 hour
# IALSRecommender: Epoch 124 of 135. Elapsed time 7.76 hour
# IALSRecommender: Epoch 125 of 135. Elapsed time 7.77 hour
# IALSRecommender: Epoch 126 of 135. Elapsed time 7.78 hour
# IALSRecommender: Epoch 127 of 135. Elapsed time 7.78 hour
# IALSRecommender: Epoch 128 of 135. Elapsed time 7.79 hour
# IALSRecommender: Epoch 129 of 135. Elapsed time 7.79 hour
# IALSRecommender: Epoch 130 of 135. Elapsed time 7.80 hour
# IALSRecommender: Epoch 131 of 135. Elapsed time 7.80 hour
# IALSRecommender: Epoch 132 of 135. Elapsed time 7.81 hour
# IALSRecommender: Epoch 133 of 135. Elapsed time 7.81 hour
# IALSRecommender: Epoch 134 of 135. Elapsed time 7.82 hour
# IALSRecommender: Epoch 135 of 135. Elapsed time 7.83 hour
# IALSRecommender: Terminating at epoch 135. Elapsed time 7.83 hour
# EvaluatorHoldout: Processed 5016 ( 100.00% ) in 4.60 sec. Users per second: 1091
# SearchBayesianSkopt: Best config evaluated with evaluator_test with constructor data for final test. Config: {'num_factors': 153, 'confidence_scaling': 'log', 'alpha': 30.61917675327107, 'epsilon': 0.001001609694823079, 'reg': 1.3918031693071822e-05, 'epochs': 135} - results:
# CUTOFF: 10 - ROC_AUC: 0.0000000, PRECISION: 0.0000000, PRECISION_RECALL_MIN_DEN: 0.0000000, RECALL: 0.0000000, MAP: 0.0000000, MRR: 0.0000000, NDCG: 0.0000000, F1: 0.0000000, HIT_RATE: 0.0000000, ARHR: 0.0000000, NOVELTY: 0.0051289, AVERAGE_POPULARITY: 0.0579821, DIVERSITY_MEAN_INTER_LIST: 0.9965311, DIVERSITY_HERFINDAHL: 0.9996332, COVERAGE_ITEM: 0.4269875, COVERAGE_ITEM_CORRECT: 0.0000000, COVERAGE_USER: 0.6311816, COVERAGE_USER_CORRECT: 0.0000000, DIVERSITY_GINI: 0.1787860, SHANNON_ENTROPY: 12.4219156,
#
#
# SearchBayesianSkopt: Saving model in result_experiments/IALSRecommender
#
# IALSRecommender: Saving model in file 'result_experiments/IALSRecommender_best_model_last'
# IALSRecommender: Saving complete
# {'num_factors': 153,
#  'confidence_scaling': 'log',
#  'alpha': 30.61917675327107,
#  'epsilon': 0.001001609694823079,
#  'reg': 1.3918031693071822e-05,
#  'epochs': 135}

# %%
test_users = pd.read_csv('data_target_users_test.csv')
test_users

# %%
recommender_alpha = P3alphaRecommender(URM_all)
recommender_alpha.fit(topK=475, alpha = 0.45, implicit = True)

recommender_alpha_ICM = P3alphaRecommender(ICM_all.T)
recommender_alpha_ICM.fit(topK=175, alpha = 0.45)
recommender_alpha_ICM.URM_train = URM_train

hybridrecommender = ItemKNNSimilarityHybridRecommender(URM_all, recommender_alpha_ICM.W_sparse, recommender_alpha.W_sparse)
hybridrecommender.fit(topK=600, alpha = 0.45)

user_id = test_users['user_id']
recommendations = hybridrecommender.recommend(user_id,cutoff = 10)

# %%
for index in range(len(recommendations)):
    #print(element)
    recommendations[index]=np.array(recommendations[index])
    #print(type(element))
print(len(recommendations))

# %%
test_users['item_list']= recommendations
#test_users['item_list'] =  test_users['item_list'].apply(lambda x: x.replace('[','').replace(']','')) 
test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])

#convert the string columns to int
#test_users['item_list'] = test_users['item_list'].astype(int)
test_users
test_users.to_csv('submission.csv', index=False)
