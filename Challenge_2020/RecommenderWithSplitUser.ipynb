# %% [markdown]
# # Recommender with splitted user

# %%
import pandas as pd
import numpy as np 
import scipy.sparse as sps
import os
import sys
import matplotlib.pyplot as plt
sys.path.append('..')

dataset = pd.read_csv('data_train.csv')
dataset
# Out:
#          row    col  data
# 0          0  10080   1.0
# 1          0  19467   1.0
# 2          1   2665   1.0
# 3          1   7494   1.0
# 4          1  17068   1.0
# ...      ...    ...   ...
# 113263  7945   2476   1.0
# 113264  7945  12319   1.0
# 113265  7945  21384   1.0
# 113266  7946   8699   1.0
# 113267  7946  19178   1.0
#
# [113268 rows x 3 columns]

# %%
users = dataset.row
items = dataset.col
data = dataset.data
URM_all = sps.coo_matrix((data, (users, items)))
URM_all = URM_all.tocsr() #fast row access -> fast access to users 
URM_all.shape
# Out:
# (7947, 25975)

# %%
items_per_user = np.ediff1d(URM_all.indptr) #tells in which position each of the rows begin
users_per_item = np.ediff1d(sps.csc_matrix(URM_all).indptr)
URM_all = sps.csr_matrix(URM_all)

# %%
items_per_user = np.sort(items_per_user) #sorting based on the single value. Losing reference to the user. 
users_per_item = np.sort(users_per_item)

# %%
ICM_df = pd.read_csv('data_ICM_title_abstract.csv')
ICM_df
# Out:
#           row    col      data
# 0           0   1185  1.015524
# 1           0   2507  0.459024
# 2           0   3534  0.227742
# 3           0   8766  0.501549
# 4           0  10862  0.297011
# ...       ...    ...       ...
# 490686  25974  12554  0.963016
# 490687  25974  13003  0.104613
# 490688  25974  16236  0.118760
# 490689  25974  18797  0.363301
# 490690  25974  19629  0.129141
#
# [490691 rows x 3 columns]

# %%
items = ICM_df.row
features = ICM_df.col
data = ICM_df.data
ICM_all = sps.coo_matrix((data, (items, features)))
ICM_all = ICM_all.tocsr() #fast row access -> fast access to users 
ICM_all.shape
# Out:
# (25975, 20000)

# %%
ICM_all = sps.csr_matrix(ICM_all)
features_per_item = np.ediff1d(ICM_all.indptr)

ICM_all = sps.csc_matrix(ICM_all)
items_per_feature = np.ediff1d(ICM_all.indptr)

ICM_all = sps.csr_matrix(ICM_all)

# %%
features_per_item = np.sort(features_per_item)
items_per_feature = np.sort(items_per_feature)

# %% [markdown]
# # Data pre-processing

# %%
from Base.Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from GraphBased.P3alphaRecommender import P3alphaRecommender
from GraphBased.RP3betaRecommender import RP3betaRecommender
from KNN.ItemKNNCBFRecommender import ItemKNNCBFRecommender
from KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender
from KNN.UserKNNCFRecommender import UserKNNCFRecommender
from KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from Base.NonPersonalizedRecommender import TopPop
from MatrixFactorization.PureSVDRecommender import PureSVDRecommender
from SLIM_BPR.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython
from GraphBased.P3alphaRecommender import P3alphaRecommender
from GraphBased.RP3betaRecommender import RP3betaRecommender
from KNN.ItemKNNCBFRecommender import ItemKNNCBFRecommender
from KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender
from KNN.UserKNNCFRecommender import UserKNNCFRecommender
from KNN.ItemKNNScoresHybridMultipleRecommender import ItemKNNScoresHybridMultipleRecommender
from KNN.ItemKNNScoresHybrid5Recommender import ItemKNNScoresHybrid5Recommender


from KNN.ItemKNNScoresHybridRecommender import ItemKNNScoresHybridRecommender


from GraphBased.RP3betaRecommender_user import RP3betaRecommender_user
from MatrixFactorization.PureSVDRecommender import PureSVDRecommender
from MatrixFactorization.IALSRecommender import IALSRecommender

from SLIM_ElasticNet.SLIMElasticNetRecommender import SLIMElasticNetRecommender
from KNN.UserKNNCFRecommender import UserKNNCFRecommender
from KNN.ItemKNNCFRecommender import ItemKNNCFRecommender

MAP_p3aplha_rp3beta_per_group = [0, 0, 0, 0, 0]
MAP_p3aplha_rp3beta_with_als_per_group = [0, 0, 0, 0, 0]
MAP_top_model_als_per_group = [0, 0, 0, 0, 0]
MAP_user_cf_cold_per_group = [0, 0, 0, 0, 0]
MAP_item_cf_cold_per_group = [0, 0, 0, 0, 0]
MAP_item_cbf_per_group = [0, 0, 0, 0, 0]
MAP_top_pop_per_group = [0, 0, 0, 0, 0]
MAP_pure_svd_per_group = [0, 0, 0, 0, 0]
MAP_slim_bpr_per_group = [0, 0, 0, 0, 0]
MAP_top_model_per_group = [0, 0, 0, 0, 0]

MAP_2018_long = [0, 0, 0, 0, 0]
MAP_2018_short = [0, 0, 0, 0, 0]
MAP_2018_seq = [0, 0, 0, 0, 0]
cutoff = 10

# %%
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.85)

evaluator_validation_earlystopping = EvaluatorHoldout(URM_validation, cutoff_list=[10])

earlystopping_keywargs = {"validation_every_n": 5,
                        "stop_on_validation": True,
                        "evaluator_object": evaluator_validation_earlystopping,
                        "lower_validations_allowed": 5,
                        "validation_metric": "MAP" ,
                        }

recommender_als = IALSRecommender(URM_train)
recommender_als.fit(epochs = 135,
        num_factors = 153,
        confidence_scaling = "log",
        alpha = 30.61917675327107,
        epsilon = 0.001001609694823079,
        reg = 1.3918031693071822e-05,
        validation_every_n = 5,
        stop_on_validation = True,
        evaluator_object = evaluator_validation_earlystopping,
        lower_validations_allowed = 5,
        validation_metric = "MAP" )
# Out:
# Warning: 52 (0.65 %) of 7947 users have no train items
# Warning: 2868 (36.09 %) of 7947 users have no sampled items
# IALSRecommender: URM Detected 52 (0.65 %) cold users.
# IALSRecommender: URM Detected 2033 (7.83 %) cold items.
# IALSRecommender: Epoch 1 of 135. Elapsed time 21.54 sec
# IALSRecommender: Epoch 2 of 135. Elapsed time 42.41 sec
# IALSRecommender: Epoch 3 of 135. Elapsed time 1.06 min
# IALSRecommender: Epoch 4 of 135. Elapsed time 1.43 min
# IALSRecommender: Validation begins...
# Deallocating Cython objects
# EvaluatorHoldout: Processed 5079 ( 100.00% ) in 5.02 sec. Users per second: 1013
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1326322, PRECISION: 0.0262650, PRECISION_RECALL_MIN_DEN: 0.1063955, RECALL: 0.1046472, MAP: 0.0479428, MRR: 0.0950682, NDCG: 0.0726364, F1: 0.0419909, HIT_RATE: 0.2626501, ARHR: 0.1056392, NOVELTY: 0.0049298, AVERAGE_POPULARITY: 0.0619067, DIVERSITY_MEAN_INTER_LIST: 0.9959800, DIVERSITY_HERFINDAHL: 0.9995784, COVERAGE_ITEM: 0.4671415, COVERAGE_ITEM_CORRECT: 0.0386526, COVERAGE_USER: 0.6391091, COVERAGE_USER_CORRECT: 0.1342645, DIVERSITY_GINI: 0.1884536, SHANNON_ENTROPY: 12.4044383,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 5 of 135. Elapsed time 1.86 min
# IALSRecommender: Epoch 6 of 135. Elapsed time 2.20 min
# IALSRecommender: Epoch 7 of 135. Elapsed time 2.55 min
# IALSRecommender: Epoch 8 of 135. Elapsed time 2.90 min
# IALSRecommender: Epoch 9 of 135. Elapsed time 3.24 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5079 ( 100.00% ) in 4.91 sec. Users per second: 1034
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1399621, PRECISION: 0.0287064, PRECISION_RECALL_MIN_DEN: 0.1159206, RECALL: 0.1137612, MAP: 0.0516142, MRR: 0.1017917, NDCG: 0.0781895, F1: 0.0458445, HIT_RATE: 0.2870644, ARHR: 0.1135182, NOVELTY: 0.0051016, AVERAGE_POPULARITY: 0.0554230, DIVERSITY_MEAN_INTER_LIST: 0.9966940, DIVERSITY_HERFINDAHL: 0.9996498, COVERAGE_ITEM: 0.4622522, COVERAGE_ITEM_CORRECT: 0.0409625, COVERAGE_USER: 0.6391091, COVERAGE_USER_CORRECT: 0.1444570, DIVERSITY_GINI: 0.1967641, SHANNON_ENTROPY: 12.5307269,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 10 of 135. Elapsed time 3.67 min
# IALSRecommender: Epoch 11 of 135. Elapsed time 4.01 min
# IALSRecommender: Epoch 12 of 135. Elapsed time 4.37 min
# IALSRecommender: Epoch 13 of 135. Elapsed time 4.73 min
# IALSRecommender: Epoch 14 of 135. Elapsed time 5.08 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5079 ( 100.00% ) in 4.95 sec. Users per second: 1027
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1402104, PRECISION: 0.0290018, PRECISION_RECALL_MIN_DEN: 0.1162595, RECALL: 0.1139974, MAP: 0.0522242, MRR: 0.1029187, NDCG: 0.0787576, F1: 0.0462398, HIT_RATE: 0.2900177, ARHR: 0.1147240, NOVELTY: 0.0051350, AVERAGE_POPULARITY: 0.0537806, DIVERSITY_MEAN_INTER_LIST: 0.9968482, DIVERSITY_HERFINDAHL: 0.9996652, COVERAGE_ITEM: 0.4553994, COVERAGE_ITEM_CORRECT: 0.0414629, COVERAGE_USER: 0.6391091, COVERAGE_USER_CORRECT: 0.1455895, DIVERSITY_GINI: 0.1960388, SHANNON_ENTROPY: 12.5468826,
#
# IALSRecommender: New best model found! Updating.
# IALSRecommender: Epoch 15 of 135. Elapsed time 5.52 min
# IALSRecommender: Epoch 16 of 135. Elapsed time 5.87 min
# IALSRecommender: Epoch 17 of 135. Elapsed time 6.25 min
# IALSRecommender: Epoch 18 of 135. Elapsed time 6.63 min
# IALSRecommender: Epoch 19 of 135. Elapsed time 6.99 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5079 ( 100.00% ) in 4.94 sec. Users per second: 1028
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1416622, PRECISION: 0.0287852, PRECISION_RECALL_MIN_DEN: 0.1165574, RECALL: 0.1144084, MAP: 0.0519376, MRR: 0.1028291, NDCG: 0.0786689, F1: 0.0459974, HIT_RATE: 0.2878519, ARHR: 0.1139069, NOVELTY: 0.0051470, AVERAGE_POPULARITY: 0.0534468, DIVERSITY_MEAN_INTER_LIST: 0.9968796, DIVERSITY_HERFINDAHL: 0.9996683, COVERAGE_ITEM: 0.4524735, COVERAGE_ITEM_CORRECT: 0.0410780, COVERAGE_USER: 0.6391091, COVERAGE_USER_CORRECT: 0.1470995, DIVERSITY_GINI: 0.1954134, SHANNON_ENTROPY: 12.5485417,
#
# IALSRecommender: Epoch 20 of 135. Elapsed time 7.43 min
# IALSRecommender: Epoch 21 of 135. Elapsed time 7.77 min
# IALSRecommender: Epoch 22 of 135. Elapsed time 8.11 min
# IALSRecommender: Epoch 23 of 135. Elapsed time 8.45 min
# IALSRecommender: Epoch 24 of 135. Elapsed time 8.79 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5079 ( 100.00% ) in 4.79 sec. Users per second: 1061
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1420057, PRECISION: 0.0286867, PRECISION_RECALL_MIN_DEN: 0.1164321, RECALL: 0.1142926, MAP: 0.0518621, MRR: 0.1028017, NDCG: 0.0785681, F1: 0.0458623, HIT_RATE: 0.2868675, ARHR: 0.1139221, NOVELTY: 0.0051526, AVERAGE_POPULARITY: 0.0533918, DIVERSITY_MEAN_INTER_LIST: 0.9968884, DIVERSITY_HERFINDAHL: 0.9996692, COVERAGE_ITEM: 0.4495476, COVERAGE_ITEM_CORRECT: 0.0407315, COVERAGE_USER: 0.6391091, COVERAGE_USER_CORRECT: 0.1473512, DIVERSITY_GINI: 0.1944431, SHANNON_ENTROPY: 12.5451966,
#
# IALSRecommender: Epoch 25 of 135. Elapsed time 9.22 min
# IALSRecommender: Epoch 26 of 135. Elapsed time 9.56 min
# IALSRecommender: Epoch 27 of 135. Elapsed time 9.90 min
# IALSRecommender: Epoch 28 of 135. Elapsed time 10.27 min
# IALSRecommender: Epoch 29 of 135. Elapsed time 10.61 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5079 ( 100.00% ) in 4.91 sec. Users per second: 1034
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1430043, PRECISION: 0.0284899, PRECISION_RECALL_MIN_DEN: 0.1159254, RECALL: 0.1138136, MAP: 0.0521542, MRR: 0.1030301, NDCG: 0.0786598, F1: 0.0455721, HIT_RATE: 0.2848986, ARHR: 0.1140212, NOVELTY: 0.0051547, AVERAGE_POPULARITY: 0.0533401, DIVERSITY_MEAN_INTER_LIST: 0.9968933, DIVERSITY_HERFINDAHL: 0.9996697, COVERAGE_ITEM: 0.4479307, COVERAGE_ITEM_CORRECT: 0.0403850, COVERAGE_USER: 0.6391091, COVERAGE_USER_CORRECT: 0.1462187, DIVERSITY_GINI: 0.1937630, SHANNON_ENTROPY: 12.5426817,
#
# IALSRecommender: Epoch 30 of 135. Elapsed time 11.04 min
# IALSRecommender: Epoch 31 of 135. Elapsed time 11.39 min
# IALSRecommender: Epoch 32 of 135. Elapsed time 11.73 min
# IALSRecommender: Epoch 33 of 135. Elapsed time 12.08 min
# IALSRecommender: Epoch 34 of 135. Elapsed time 12.42 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5079 ( 100.00% ) in 4.81 sec. Users per second: 1056
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1416493, PRECISION: 0.0286867, PRECISION_RECALL_MIN_DEN: 0.1162290, RECALL: 0.1140718, MAP: 0.0517908, MRR: 0.1020243, NDCG: 0.0783749, F1: 0.0458445, HIT_RATE: 0.2868675, ARHR: 0.1132520, NOVELTY: 0.0051557, AVERAGE_POPULARITY: 0.0533916, DIVERSITY_MEAN_INTER_LIST: 0.9968845, DIVERSITY_HERFINDAHL: 0.9996688, COVERAGE_ITEM: 0.4471992, COVERAGE_ITEM_CORRECT: 0.0405005, COVERAGE_USER: 0.6391091, COVERAGE_USER_CORRECT: 0.1464704, DIVERSITY_GINI: 0.1933516, SHANNON_ENTROPY: 12.5396408,
#
# IALSRecommender: Epoch 35 of 135. Elapsed time 12.85 min
# IALSRecommender: Epoch 36 of 135. Elapsed time 13.19 min
# IALSRecommender: Epoch 37 of 135. Elapsed time 13.54 min
# IALSRecommender: Epoch 38 of 135. Elapsed time 13.88 min
# IALSRecommender: Epoch 39 of 135. Elapsed time 14.22 min
# IALSRecommender: Validation begins...
# EvaluatorHoldout: Processed 5079 ( 100.00% ) in 4.81 sec. Users per second: 1055
# IALSRecommender: CUTOFF: 10 - ROC_AUC: 0.1420020, PRECISION: 0.0285686, PRECISION_RECALL_MIN_DEN: 0.1155829, RECALL: 0.1134809, MAP: 0.0516071, MRR: 0.1020051, NDCG: 0.0781384, F1: 0.0456459, HIT_RATE: 0.2856862, ARHR: 0.1130491, NOVELTY: 0.0051565, AVERAGE_POPULARITY: 0.0533305, DIVERSITY_MEAN_INTER_LIST: 0.9968856, DIVERSITY_HERFINDAHL: 0.9996689, COVERAGE_ITEM: 0.4463138, COVERAGE_ITEM_CORRECT: 0.0401925, COVERAGE_USER: 0.6391091, COVERAGE_USER_CORRECT: 0.1463445, DIVERSITY_GINI: 0.1931712, SHANNON_ENTROPY: 12.5386036,
#
# IALSRecommender: Convergence reached! Terminating at epoch 40. Best value for 'MAP' at epoch 15 is 0.0522. Elapsed time 14.65 min
# IALSRecommender: Epoch 40 of 135. Elapsed time 14.65 min

# %%
from KNN.ItemKNNScoresHybrid5Recommender import ItemKNNScoresHybrid5Recommender

# %%
for index in range(0, 5):
        URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.85)

        # ----- FIRST ------ #
        recommender_alpha = P3alphaRecommender(URM_train)
        recommender_alpha.fit(topK=170, alpha = 0.45, implicit = True)

        recommender_beta_ICM = RP3betaRecommender(ICM_all.T)
        recommender_beta_ICM.fit(topK=70, alpha=0.2, beta=0.5, implicit=False)
        recommender_beta_ICM.URM_train = URM_train

        hybridrecommender = ItemKNNSimilarityHybridRecommender(URM_train, recommender_alpha.W_sparse, recommender_beta_ICM.W_sparse)
        hybridrecommender.fit(topK=200, alpha = 0.1)


        # ----- SECOND  ------ #
        hybridrecommender_with_als = ItemKNNScoresHybridMultipleRecommender(URM_train, recommender_als, recommender_alpha, recommender_beta_ICM)
        hybridrecommender_with_als.fit(alpha = 0.3, beta=0.1)

        # ----- THIRD ------ #
        recommender_userKNN_top_model = UserKNNCFRecommender(URM_train)
        recommender_userKNN_top_model.fit(topK= 75, shrink = 200)

        recommender_SVD_top_model = PureSVDRecommender(URM_train)
        recommender_SVD_top_model.fit(num_factors = 1200)

        recommender_alpha_top_model = P3alphaRecommender(URM_train)
        recommender_alpha_top_model.fit(topK=350, alpha = 0.45, implicit = True)

        recommender_beta_ICM_top_model = RP3betaRecommender(ICM_all.T)
        recommender_beta_ICM_top_model.fit(topK=70, alpha=0.35, beta=0.4, implicit=False)
        recommender_beta_ICM_top_model.URM_train = URM_train

        hybridrecommender_p3_rp3_top_model = ItemKNNSimilarityHybridRecommender(URM_train, recommender_alpha_top_model.W_sparse, recommender_beta_ICM_top_model.W_sparse)
        hybridrecommender_p3_rp3_top_model.fit(topK=450, alpha = 0.1)

        hybridrecommender_top_model = ItemKNNScoresHybridMultipleRecommender(URM_train, hybridrecommender_p3_rp3_top_model, recommender_userKNN_top_model, recommender_SVD_top_model)
        hybridrecommender_top_model.fit(alpha = 0.7, beta=0.25)


        # ------ FORTH COPY FROM 2018 REPO ------ #
        # SHORT ---- LONG ----- SEQ

        recommender_slim_bpr_2018 = SLIM_BPR_Cython(URM_train, recompile_cython=False)
        recommender_slim_bpr_2018.fit(epochs=200, batch_size=1000, sgd_mode='adagrad', learning_rate=0.001, positive_threshold_BPR=1, topK=400)

        recommender_user_cf_2018 = UserKNNCFRecommender(URM_train)
        recommender_user_cf_2018.fit(shrink=100, topK=150, feature_weighting = "TF-IDF")

        recommender_item_cf_2018 = ItemKNNCFRecommender(URM_train)
        recommender_item_cf_2018.fit(shrink=200, topK=750, feature_weighting = 'TF-IDF', similarity = 'tversky')

        recommender_cbf_2018 = ItemKNNCBFRecommender(URM_train, ICM_all)
        recommender_cbf_2018.fit(topK=600, shrink=200, feature_weighting = 'TF-IDF')

        hybridrecommender_2018_short = ItemKNNScoresHybrid5Recommender(URM_train, recommender_user_cf_2018, recommender_item_cf_2018, recommender_cbf_2018, recommender_als, recommender_slim_bpr_2018)
        hybridrecommender_2018_short.fit(first = 0.03, second=0.25, third=0.15, forth=0.3, fifth=0.6)

        hybridrecommender_2018_long = ItemKNNScoresHybrid5Recommender(URM_train, recommender_user_cf_2018, recommender_item_cf_2018, recommender_cbf_2018, recommender_als, recommender_slim_bpr_2018)
        hybridrecommender_2018_long.fit(first = 0.03, second=0.35, third=0.2, forth=0.3, fifth=0.22)

        hybridrecommender_2018_seq = ItemKNNScoresHybrid5Recommender(URM_train, recommender_user_cf_2018, recommender_item_cf_2018, recommender_cbf_2018, recommender_als, recommender_slim_bpr_2018)
        hybridrecommender_2018_seq.fit(first = 0.5, second=0.1, third=0.72, forth=0.14, fifth=2.065)

        grouped_users = dataset.groupby(['row']).count()
        sorted_users = grouped_users.sort_values(by=['col'], ascending=True)
        sorted_users = sorted_users.index.to_numpy()

        block_size = int(len(sorted_users)*0.20)

        for group_id in range(0, 5):
        
                start_pos = group_id*block_size
                end_pos = min((group_id+1)*block_size, len(sorted_users))
                
                users_in_group = sorted_users[start_pos:end_pos]
                
                users_not_in_group_flag = np.isin(sorted_users, users_in_group, invert = True)
                users_not_in_group = sorted_users[users_not_in_group_flag]
                
                evaluator_p3_rp3 = EvaluatorHoldout(URM_validation, cutoff_list=[cutoff], ignore_users = users_not_in_group)
                
                results, _ = evaluator_p3_rp3.evaluateRecommender(hybridrecommender)
                MAP_p3aplha_rp3beta_per_group[group_id] += results[cutoff]["MAP"]

                results, _ = evaluator_p3_rp3.evaluateRecommender(hybridrecommender_with_als)
                MAP_p3aplha_rp3beta_with_als_per_group[group_id] += results[cutoff]["MAP"]

                results, _ = evaluator_p3_rp3.evaluateRecommender(hybridrecommender_top_model)
                MAP_top_model_per_group[group_id] += results[cutoff]["MAP"]

                results, _ = evaluator_p3_rp3.evaluateRecommender(hybridrecommender_2018_long)
                MAP_2018_long[group_id] += results[cutoff]["MAP"]

                results, _ = evaluator_p3_rp3.evaluateRecommender(hybridrecommender_2018_short)
                MAP_2018_short[group_id] += results[cutoff]["MAP"]

                results, _ = evaluator_p3_rp3.evaluateRecommender(hybridrecommender_2018_seq)
                MAP_2018_seq[group_id] += results[cutoff]["MAP"]
# Out:
# Elapsed time 2.13 sec
# Processed 7947 ( 100.00% ) in 0.17 seconds. BPR loss is 1.08E-03. Sample per second: 46577
# SLIM_BPR_Recommender: Epoch 80 of 200. Elapsed time 2.15 sec
# Processed 7947 ( 100.00% ) in 0.19 seconds. BPR loss is 1.14E-03. Sample per second: 41109
# SLIM_BPR_Recommender: Epoch 81 of 200. Elapsed time 2.17 sec
# Processed 7947 ( 100.00% ) in 0.22 seconds. BPR loss is 1.17E-03. Sample per second: 36527
# SLIM_BPR_Recommender: Epoch 82 of 200. Elapsed time 2.20 sec
# Processed 7947 ( 100.00% ) in 0.24 seconds. BPR loss is 1.30E-03. Sample per second: 32745
# SLIM_BPR_Recommender: Epoch 83 of 200. Elapsed time 2.22 sec
# Processed 7947 ( 100.00% ) in 0.27 seconds. BPR loss is 1.13E-03. Sample per second: 29430
# SLIM_BPR_Recommender: Epoch 84 of 200. Elapsed time 2.25 sec
# Processed 7947 ( 100.00% ) in 0.30 seconds. BPR loss is 1.21E-03. Sample per second: 26797
# SLIM_BPR_Recommender: Epoch 85 of 200. Elapsed time 2.28 sec
# Processed 7947 ( 100.00% ) in 0.32 seconds. BPR loss is 1.23E-03. Sample per second: 24650
# SLIM_BPR_Recommender: Epoch 86 of 200. Elapsed time 2.30 sec
# Processed 7947 ( 100.00% ) in 0.35 seconds. BPR loss is 1.21E-03. Sample per second: 22812
# SLIM_BPR_Recommender: Epoch 87 of 200. Elapsed time 2.33 sec
# Processed 7947 ( 100.00% ) in 0.37 seconds. BPR loss is 1.27E-03. Sample per second: 21276
# SLIM_BPR_Recommender: Epoch 88 of 200. Elapsed time 2.35 sec
# Processed 7947 ( 100.00% ) in 0.40 seconds. BPR loss is 1.23E-03. Sample per second: 19882
# SLIM_BPR_Recommender: Epoch 89 of 200. Elapsed time 2.38 sec
# Processed 7947 ( 100.00% ) in 0.42 seconds. BPR loss is 1.21E-03. Sample per second: 18708
# SLIM_BPR_Recommender: Epoch 90 of 200. Elapsed time 2.40 sec
# Processed 7947 ( 100.00% ) in 0.45 seconds. BPR loss is 1.30E-03. Sample per second: 17601
# SLIM_BPR_Recommender: Epoch 91 of 200. Elapsed time 2.43 sec
# Processed 7947 ( 100.00% ) in 0.47 seconds. BPR loss is 1.29E-03. Sample per second: 16747
# SLIM_BPR_Recommender: Epoch 92 of 200. Elapsed time 2.45 sec
# Processed 7947 ( 100.00% ) in 0.50 seconds. BPR loss is 1.30E-03. Sample per second: 15835
# SLIM_BPR_Recommender: Epoch 93 of 200. Elapsed time 2.48 sec
# Processed 7947 ( 100.00% ) in 0.53 seconds. BPR loss is 1.31E-03. Sample per second: 15090
# SLIM_BPR_Recommender: Epoch 94 of 200. Elapsed time 2.51 sec
# Processed 7947 ( 100.00% ) in 0.56 seconds. BPR loss is 1.33E-03. Sample per second: 14315
# SLIM_BPR_Recommender: Epoch 95 of 200. Elapsed time 2.53 sec
# Processed 7947 ( 100.00% ) in 0.59 seconds. BPR loss is 1.30E-03. Sample per second: 13395
# SLIM_BPR_Recommender: Epoch 96 of 200. Elapsed time 2.58 sec
# Processed 7947 ( 100.00% ) in 0.64 seconds. BPR loss is 1.35E-03. Sample per second: 12445
# SLIM_BPR_Recommender: Epoch 97 of 200. Elapsed time 2.62 sec
# Processed 7947 ( 100.00% ) in 0.67 seconds. BPR loss is 1.37E-03. Sample per second: 11904
# SLIM_BPR_Recommender: Epoch 98 of 200. Elapsed time 2.65 sec
# Processed 7947 ( 100.00% ) in 0.69 seconds. BPR loss is 1.43E-03. Sample per second: 11473
# SLIM_BPR_Recommender: Epoch 99 of 200. Elapsed time 2.67 sec
# Processed 7947 ( 100.00% ) in 0.72 seconds. BPR loss is 1.42E-03. Sample per second: 11001
# SLIM_BPR_Recommender: Epoch 100 of 200. Elapsed time 2.70 sec
# Processed 7947 ( 100.00% ) in 0.75 seconds. BPR loss is 1.42E-03. Sample per second: 10605
# SLIM_BPR_Recommender: Epoch 101 of 200. Elapsed time 2.73 sec
# Processed 7947 ( 100.00% ) in 0.77 seconds. BPR loss is 1.45E-03. Sample per second: 10267
# SLIM_BPR_Recommender: Epoch 102 of 200. Elapsed time 2.75 sec
# Processed 7947 ( 100.00% ) in 0.81 seconds. BPR loss is 1.44E-03. Sample per second: 9858
# SLIM_BPR_Recommender: Epoch 103 of 200. Elapsed time 2.80 sec
# Processed 7947 ( 100.00% ) in 0.86 seconds. BPR loss is 1.48E-03. Sample per second: 9293
# SLIM_BPR_Recommender: Epoch 104 of 200. Elapsed time 2.84 sec
# Processed 7947 ( 100.00% ) in 0.88 seconds. BPR loss is 1.46E-03. Sample per second: 9001
# SLIM_BPR_Recommender: Epoch 105 of 200. Elapsed time 2.86 sec
# Processed 7947 ( 100.00% ) in 0.91 seconds. BPR loss is 1.45E-03. Sample per second: 8761
# SLIM_BPR_Recommender: Epoch 106 of 200. Elapsed time 2.89 sec
# Processed 7947 ( 100.00% ) in 0.94 seconds. BPR loss is 1.51E-03. Sample per second: 8486
# SLIM_BPR_Recommender: Epoch 107 of 200. Elapsed time 2.92 sec
# Processed 7947 ( 100.00% ) in 0.96 seconds. BPR loss is 1.60E-03. Sample per second: 8263
# SLIM_BPR_Recommender: Epoch 108 of 200. Elapsed time 2.94 sec
# Processed 7947 ( 100.00% ) in 0.99 seconds. BPR loss is 1.47E-03. Sample per second: 8028
# SLIM_BPR_Recommender: Epoch 109 of 200. Elapsed time 2.97 sec
# Processed 7947 ( 100.00% ) in 1.02 seconds. BPR loss is 1.53E-03. Sample per second: 7786
# SLIM_BPR_Recommender: Epoch 110 of 200. Elapsed time 3.00 sec
# Processed 7947 ( 100.00% ) in 0.05 seconds. BPR loss is 1.58E-03. Sample per second: 159958
# SLIM_BPR_Recommender: Epoch 111 of 200. Elapsed time 3.03 sec
# Processed 7947 ( 100.00% ) in 0.07 seconds. BPR loss is 1.53E-03. Sample per second: 108624
# SLIM_BPR_Recommender: Epoch 112 of 200. Elapsed time 3.05 sec
# Processed 7947 ( 100.00% ) in 0.10 seconds. BPR loss is 1.61E-03. Sample per second: 79245
# SLIM_BPR_Recommender: Epoch 113 of 200. Elapsed time 3.08 sec
# Processed 7947 ( 100.00% ) in 0.13 seconds. BPR loss is 1.60E-03. Sample per second: 62994
# SLIM_BPR_Recommender: Epoch 114 of 200. Elapsed time 3.11 sec
# Processed 7947 ( 100.00% ) in 0.15 seconds. BPR loss is 1.75E-03. Sample per second: 52200
# SLIM_BPR_Recommender: Epoch 115 of 200. Elapsed time 3.13 sec
# Processed 7947 ( 100.00% ) in 0.18 seconds. BPR loss is 1.63E-03. Sample per second: 44652
# SLIM_BPR_Recommender: Epoch 116 of 200. Elapsed time 3.16 sec
# Processed 7947 ( 100.00% ) in 0.20 seconds. BPR loss is 1.64E-03. Sample per second: 39277
# SLIM_BPR_Recommender: Epoch 117 of 200. Elapsed time 3.18 sec
# Processed 7947 ( 100.00% ) in 0.23 seconds. BPR loss is 1.67E-03. Sample per second: 33963
# SLIM_BPR_Recommender: Epoch 118 of 200. Elapsed time 3.21 sec
# Processed 7947 ( 100.00% ) in 0.27 seconds. BPR loss is 1.68E-03. Sample per second: 29458
# SLIM_BPR_Recommender: Epoch 119 of 200. Elapsed time 3.25 sec
# Processed 7947 ( 100.00% ) in 0.32 seconds. BPR loss is 1.70E-03. Sample per second: 24643
# SLIM_BPR_Recommender: Epoch 120 of 200. Elapsed time 3.30 sec
# Processed 7947 ( 100.00% ) in 0.36 seconds. BPR loss is 1.73E-03. Sample per second: 22257
# SLIM_BPR_Recommender: Epoch 121 of 200. Elapsed time 3.34 sec
# Processed 7947 ( 100.00% ) in 0.39 seconds. BPR loss is 1.78E-03. Sample per second: 20558
# SLIM_BPR_Recommender: Epoch 122 of 200. Elapsed time 3.37 sec
# Processed 7947 ( 100.00% ) in 0.42 seconds. BPR loss is 1.72E-03. Sample per second: 19093
# SLIM_BPR_Recommender: Epoch 123 of 200. Elapsed time 3.39 sec
# Processed 7947 ( 100.00% ) in 0.44 seconds. BPR loss is 1.73E-03. Sample per second: 17913
# SLIM_BPR_Recommender: Epoch 124 of 200. Elapsed time 3.42 sec
# Processed 7947 ( 100.00% ) in 0.47 seconds. BPR loss is 1.77E-03. Sample per second: 16823
# SLIM_BPR_Recommender: Epoch 125 of 200. Elapsed time 3.45 sec
# Processed 7947 ( 100.00% ) in 0.50 seconds. BPR loss is 1.76E-03. Sample per second: 15989
# SLIM_BPR_Recommender: Epoch 126 of 200. Elapsed time 3.48 sec
# Processed 7947 ( 100.00% ) in 0.53 seconds. BPR loss is 1.80E-03. Sample per second: 14996
# SLIM_BPR_Recommender: Epoch 127 of 200. Elapsed time 3.51 sec
# Processed 7947 ( 100.00% ) in 0.56 seconds. BPR loss is 1.82E-03. Sample per second: 14270
# SLIM_BPR_Recommender: Epoch 128 of 200. Elapsed time 3.54 sec
# Processed 7947 ( 100.00% ) in 0.58 seconds. BPR loss is 1.75E-03. Sample per second: 13592
# SLIM_BPR_Recommender: Epoch 129 of 200. Elapsed time 3.56 sec
# Processed 7947 ( 100.00% ) in 0.61 seconds. BPR loss is 1.84E-03. Sample per second: 12990
# SLIM_BPR_Recommender: Epoch 130 of 200. Elapsed time 3.59 sec
# Processed 7947 ( 100.00% ) in 0.64 seconds. BPR loss is 1.93E-03. Sample per second: 12417
# SLIM_BPR_Recommender: Epoch 131 of 200. Elapsed time 3.62 sec
# Processed 7947 ( 100.00% ) in 0.67 seconds. BPR loss is 1.83E-03. Sample per second: 11922
# SLIM_BPR_Recommender: Epoch 132 of 200. Elapsed time 3.65 sec
# Processed 7947 ( 100.00% ) in 0.69 seconds. BPR loss is 1.83E-03. Sample per second: 11449
# SLIM_BPR_Recommender: Epoch 133 of 200. Elapsed time 3.67 sec
# Processed 7947 ( 100.00% ) in 0.72 seconds. BPR loss is 2.14E-03. Sample per second: 11013
# SLIM_BPR_Recommender: Epoch 134 of 200. Elapsed time 3.70 sec
# Processed 7947 ( 100.00% ) in 0.75 seconds. BPR loss is 1.85E-03. Sample per second: 10642
# SLIM_BPR_Recommender: Epoch 135 of 200. Elapsed time 3.73 sec
# Processed 7947 ( 100.00% ) in 0.78 seconds. BPR loss is 1.98E-03. Sample per second: 10233
# SLIM_BPR_Recommender: Epoch 136 of 200. Elapsed time 3.76 sec
# Processed 7947 ( 100.00% ) in 0.81 seconds. BPR loss is 1.93E-03. Sample per second: 9863
# SLIM_BPR_Recommender: Epoch 137 of 200. Elapsed time 3.78 sec
# Processed 7947 ( 100.00% ) in 0.84 seconds. BPR loss is 2.01E-03. Sample per second: 9461
# SLIM_BPR_Recommender: Epoch 138 of 200. Elapsed time 3.82 sec
# Processed 7947 ( 100.00% ) in 0.88 seconds. BPR loss is 1.94E-03. Sample per second: 9030
# SLIM_BPR_Recommender: Epoch 139 of 200. Elapsed time 3.86 sec
# Processed 7947 ( 100.00% ) in 0.91 seconds. BPR loss is 1.99E-03. Sample per second: 8718
# SLIM_BPR_Recommender: Epoch 140 of 200. Elapsed time 3.89 sec
# Processed 7947 ( 100.00% ) in 0.94 seconds. BPR loss is 1.92E-03. Sample per second: 8438
# SLIM_BPR_Recommender: Epoch 141 of 200. Elapsed time 3.92 sec
# Processed 7947 ( 100.00% ) in 0.98 seconds. BPR loss is 2.01E-03. Sample per second: 8135
# SLIM_BPR_Recommender: Epoch 142 of 200. Elapsed time 3.96 sec
# Processed 7947 ( 100.00% ) in 1.01 seconds. BPR loss is 2.01E-03. Sample per second: 7833
# SLIM_BPR_Recommender: Epoch 143 of 200. Elapsed time 4.00 sec
# Processed 7947 ( 100.00% ) in 0.04 seconds. BPR loss is 1.99E-03. Sample per second: 186097
# SLIM_BPR_Recommender: Epoch 144 of 200. Elapsed time 4.02 sec
# Processed 7947 ( 100.00% ) in 0.07 seconds. BPR loss is 2.00E-03. Sample per second: 109661
# SLIM_BPR_Recommender: Epoch 145 of 200. Elapsed time 4.05 sec
# Processed 7947 ( 100.00% ) in 0.10 seconds. BPR loss is 1.96E-03. Sample per second: 78608
# SLIM_BPR_Recommender: Epoch 146 of 200. Elapsed time 4.08 sec
# Processed 7947 ( 100.00% ) in 0.13 seconds. BPR loss is 2.08E-03. Sample per second: 63412
# SLIM_BPR_Recommender: Epoch 147 of 200. Elapsed time 4.10 sec
# Processed 7947 ( 100.00% ) in 0.15 seconds. BPR loss is 2.09E-03. Sample per second: 52761
# SLIM_BPR_Recommender: Epoch 148 of 200. Elapsed time 4.13 sec
# Processed 7947 ( 100.00% ) in 0.17 seconds. BPR loss is 2.10E-03. Sample per second: 45564
# SLIM_BPR_Recommender: Epoch 149 of 200. Elapsed time 4.15 sec
# Processed 7947 ( 100.00% ) in 0.20 seconds. BPR loss is 2.26E-03. Sample per second: 38926
# SLIM_BPR_Recommender: Epoch 150 of 200. Elapsed time 4.18 sec
# Processed 7947 ( 100.00% ) in 0.23 seconds. BPR loss is 2.15E-03. Sample per second: 34998
# SLIM_BPR_Recommender: Epoch 151 of 200. Elapsed time 4.21 sec
# Processed 7947 ( 100.00% ) in 0.25 seconds. BPR loss is 2.17E-03. Sample per second: 31324
# SLIM_BPR_Recommender: Epoch 152 of 200. Elapsed time 4.23 sec
# Processed 7947 ( 100.00% ) in 0.28 seconds. BPR loss is 2.16E-03. Sample per second: 28493
# SLIM_BPR_Recommender: Epoch 153 of 200. Elapsed time 4.26 sec
# Processed 7947 ( 100.00% ) in 0.31 seconds. BPR loss is 2.16E-03. Sample per second: 25957
# SLIM_BPR_Recommender: Epoch 154 of 200. Elapsed time 4.29 sec
# Processed 7947 ( 100.00% ) in 0.34 seconds. BPR loss is 2.19E-03. Sample per second: 23658
# SLIM_BPR_Recommender: Epoch 155 of 200. Elapsed time 4.32 sec
# Processed 7947 ( 100.00% ) in 0.36 seconds. BPR loss is 2.25E-03. Sample per second: 21978
# SLIM_BPR_Recommender: Epoch 156 of 200. Elapsed time 4.34 sec
# Processed 7947 ( 100.00% ) in 0.39 seconds. BPR loss is 2.19E-03. Sample per second: 20518
# SLIM_BPR_Recommender: Epoch 157 of 200. Elapsed time 4.37 sec
# Processed 7947 ( 100.00% ) in 0.41 seconds. BPR loss is 2.18E-03. Sample per second: 19278
# SLIM_BPR_Recommender: Epoch 158 of 200. Elapsed time 4.39 sec
# Processed 7947 ( 100.00% ) in 0.44 seconds. BPR loss is 2.24E-03. Sample per second: 18087
# SLIM_BPR_Recommender: Epoch 159 of 200. Elapsed time 4.42 sec
# Processed 7947 ( 100.00% ) in 0.46 seconds. BPR loss is 2.33E-03. Sample per second: 17206
# SLIM_BPR_Recommender: Epoch 160 of 200. Elapsed time 4.44 sec
# Processed 7947 ( 100.00% ) in 0.49 seconds. BPR loss is 2.33E-03. Sample per second: 16252
# SLIM_BPR_Recommender: Epoch 161 of 200. Elapsed time 4.47 sec
# Processed 7947 ( 100.00% ) in 0.51 seconds. BPR loss is 2.38E-03. Sample per second: 15481
# SLIM_BPR_Recommender: Epoch 162 of 200. Elapsed time 4.49 sec
# Processed 7947 ( 100.00% ) in 0.54 seconds. BPR loss is 2.42E-03. Sample per second: 14710
# SLIM_BPR_Recommender: Epoch 163 of 200. Elapsed time 4.52 sec
# Processed 7947 ( 100.00% ) in 0.57 seconds. BPR loss is 2.40E-03. Sample per second: 14000
# SLIM_BPR_Recommender: Epoch 164 of 200. Elapsed time 4.55 sec
# Processed 7947 ( 100.00% ) in 0.59 seconds. BPR loss is 2.38E-03. Sample per second: 13456
# SLIM_BPR_Recommender: Epoch 165 of 200. Elapsed time 4.57 sec
# Processed 7947 ( 100.00% ) in 0.62 seconds. BPR loss is 2.39E-03. Sample per second: 12907
# SLIM_BPR_Recommender: Epoch 166 of 200. Elapsed time 4.59 sec
# Processed 7947 ( 100.00% ) in 0.64 seconds. BPR loss is 2.34E-03. Sample per second: 12399
# SLIM_BPR_Recommender: Epoch 167 of 200. Elapsed time 4.62 sec
# Processed 7947 ( 100.00% ) in 0.67 seconds. BPR loss is 2.37E-03. Sample per second: 11936
# SLIM_BPR_Recommender: Epoch 168 of 200. Elapsed time 4.64 sec
# Processed 7947 ( 100.00% ) in 0.69 seconds. BPR loss is 2.42E-03. Sample per second: 11497
# SLIM_BPR_Recommender: Epoch 169 of 200. Elapsed time 4.67 sec
# Processed 7947 ( 100.00% ) in 0.72 seconds. BPR loss is 2.45E-03. Sample per second: 11036
# SLIM_BPR_Recommender: Epoch 170 of 200. Elapsed time 4.70 sec
# Processed 7947 ( 100.00% ) in 0.75 seconds. BPR loss is 2.45E-03. Sample per second: 10620
# SLIM_BPR_Recommender: Epoch 171 of 200. Elapsed time 4.73 sec
# Processed 7947 ( 100.00% ) in 0.78 seconds. BPR loss is 2.48E-03. Sample per second: 10217
# SLIM_BPR_Recommender: Epoch 172 of 200. Elapsed time 4.76 sec
# Processed 7947 ( 100.00% ) in 0.81 seconds. BPR loss is 2.50E-03. Sample per second: 9767
# SLIM_BPR_Recommender: Epoch 173 of 200. Elapsed time 4.80 sec
# Processed 7947 ( 100.00% ) in 0.85 seconds. BPR loss is 2.44E-03. Sample per second: 9312
# SLIM_BPR_Recommender: Epoch 174 of 200. Elapsed time 4.83 sec
# Processed 7947 ( 100.00% ) in 0.88 seconds. BPR loss is 2.51E-03. Sample per second: 9028
# SLIM_BPR_Recommender: Epoch 175 of 200. Elapsed time 4.86 sec
# Processed 7947 ( 100.00% ) in 0.91 seconds. BPR loss is 2.45E-03. Sample per second: 8768
# SLIM_BPR_Recommender: Epoch 176 of 200. Elapsed time 4.89 sec
# Processed 7947 ( 100.00% ) in 0.93 seconds. BPR loss is 2.50E-03. Sample per second: 8510
# SLIM_BPR_Recommender: Epoch 177 of 200. Elapsed time 4.91 sec
# Processed 7947 ( 100.00% ) in 0.96 seconds. BPR loss is 2.53E-03. Sample per second: 8310
# SLIM_BPR_Recommender: Epoch 178 of 200. Elapsed time 4.94 sec
# Processed 7947 ( 100.00% ) in 0.98 seconds. BPR loss is 2.52E-03. Sample per second: 8089
# SLIM_BPR_Recommender: Epoch 179 of 200. Elapsed time 4.96 sec
# Processed 7947 ( 100.00% ) in 1.01 seconds. BPR loss is 2.54E-03. Sample per second: 7882
# SLIM_BPR_Recommender: Epoch 180 of 200. Elapsed time 4.99 sec
# Processed 7947 ( 100.00% ) in 0.04 seconds. BPR loss is 2.52E-03. Sample per second: 204519
# SLIM_BPR_Recommender: Epoch 181 of 200. Elapsed time 5.02 sec
# Processed 7947 ( 100.00% ) in 0.07 seconds. BPR loss is 2.58E-03. Sample per second: 108150
# SLIM_BPR_Recommender: Epoch 182 of 200. Elapsed time 5.06 sec
# Processed 7947 ( 100.00% ) in 0.11 seconds. BPR loss is 2.68E-03. Sample per second: 69281
# SLIM_BPR_Recommender: Epoch 183 of 200. Elapsed time 5.09 sec
# Processed 7947 ( 100.00% ) in 0.17 seconds. BPR loss is 2.68E-03. Sample per second: 48059
# SLIM_BPR_Recommender: Epoch 184 of 200. Elapsed time 5.14 sec
# Processed 7947 ( 100.00% ) in 0.19 seconds. BPR loss is 2.61E-03. Sample per second: 41558
# SLIM_BPR_Recommender: Epoch 185 of 200. Elapsed time 5.17 sec
# Processed 7947 ( 100.00% ) in 0.21 seconds. BPR loss is 2.69E-03. Sample per second: 37031
# SLIM_BPR_Recommender: Epoch 186 of 200. Elapsed time 5.19 sec
# Processed 7947 ( 100.00% ) in 0.24 seconds. BPR loss is 2.64E-03. Sample per second: 33077
# SLIM_BPR_Recommender: Epoch 187 of 200. Elapsed time 5.22 sec
# Processed 7947 ( 100.00% ) in 0.26 seconds. BPR loss is 2.76E-03. Sample per second: 30022
# SLIM_BPR_Recommender: Epoch 188 of 200. Elapsed time 5.24 sec
# Processed 7947 ( 100.00% ) in 0.29 seconds. BPR loss is 2.79E-03. Sample per second: 27480
# SLIM_BPR_Recommender: Epoch 189 of 200. Elapsed time 5.27 sec
# Processed 7947 ( 100.00% ) in 0.31 seconds. BPR loss is 2.68E-03. Sample per second: 25438
# SLIM_BPR_Recommender: Epoch 190 of 200. Elapsed time 5.29 sec
# Processed 7947 ( 100.00% ) in 0.34 seconds. BPR loss is 2.71E-03. Sample per second: 23488
# SLIM_BPR_Recommender: Epoch 191 of 200. Elapsed time 5.32 sec
# Processed 7947 ( 100.00% ) in 0.37 seconds. BPR loss is 2.77E-03. Sample per second: 21766
# SLIM_BPR_Recommender: Epoch 192 of 200. Elapsed time 5.34 sec
# Processed 7947 ( 100.00% ) in 0.39 seconds. BPR loss is 2.83E-03. Sample per second: 20128
# SLIM_BPR_Recommender: Epoch 193 of 200. Elapsed time 5.37 sec
# Processed 7947 ( 100.00% ) in 0.42 seconds. BPR loss is 2.82E-03. Sample per second: 18809
# SLIM_BPR_Recommender: Epoch 194 of 200. Elapsed time 5.40 sec
# Processed 7947 ( 100.00% ) in 0.45 seconds. BPR loss is 2.85E-03. Sample per second: 17559
# SLIM_BPR_Recommender: Epoch 195 of 200. Elapsed time 5.43 sec
# Processed 7947 ( 100.00% ) in 0.48 seconds. BPR loss is 2.75E-03. Sample per second: 16596
# SLIM_BPR_Recommender: Epoch 196 of 200. Elapsed time 5.46 sec
# Processed 7947 ( 100.00% ) in 0.51 seconds. BPR loss is 2.82E-03. Sample per second: 15520
# SLIM_BPR_Recommender: Epoch 197 of 200. Elapsed time 5.49 sec
# Processed 7947 ( 100.00% ) in 0.54 seconds. BPR loss is 2.75E-03. Sample per second: 14723
# SLIM_BPR_Recommender: Epoch 198 of 200. Elapsed time 5.52 sec
# Processed 7947 ( 100.00% ) in 0.56 seconds. BPR loss is 2.84E-03. Sample per second: 14085
# SLIM_BPR_Recommender: Epoch 199 of 200. Elapsed time 5.54 sec
# Processed 7947 ( 100.00% ) in 0.59 seconds. BPR loss is 2.88E-03. Sample per second: 13383
# SLIM_BPR_Recommender: Epoch 200 of 200. Elapsed time 5.57 sec
# SLIM_BPR_Recommender: Terminating at epoch 200. Elapsed time 23.98 sec
# Deallocating Cython objects
# UserKNNCFRecommender: URM Detected 45 (0.57 %) cold users.
# UserKNNCFRecommender: URM Detected 1937 (7.46 %) cold items.
# Similarity column 7947 ( 100 % ), 16841.90 column/sec, elapsed time 0.01 min
# ItemKNNCFRecommender: URM Detected 45 (0.57 %) cold users.
# ItemKNNCFRecommender: URM Detected 1937 (7.46 %) cold items.
# Similarity column 25975 ( 100 % ), 5656.49 column/sec, elapsed time 0.08 min
# ItemKNNCBFRecommender: URM Detected 45 (0.57 %) cold users.
# ItemKNNCBFRecommender: URM Detected 1937 (7.46 %) cold items.
# Similarity column 25975 ( 100 % ), 3641.94 column/sec, elapsed time 0.12 min
# ItemKNNScoresHybrid5Recommender: URM Detected 45 (0.57 %) cold users.
# ItemKNNScoresHybrid5Recommender: URM Detected 1937 (7.46 %) cold items.
# ItemKNNScoresHybrid5Recommender: URM Detected 45 (0.57 %) cold users.
# ItemKNNScoresHybrid5Recommender: URM Detected 1937 (7.46 %) cold items.
# ItemKNNScoresHybrid5Recommender: URM Detected 45 (0.57 %) cold users.
# ItemKNNScoresHybrid5Recommender: URM Detected 1937 (7.46 %) cold items.
# EvaluatorHoldout: Ignoring 6358 Users
# EvaluatorHoldout: Processed 493 ( 100.00% ) in 0.33 sec. Users per second: 1484
# shape of item_weights: (493, 25975)
# EvaluatorHoldout: Processed 493 ( 100.00% ) in 0.62 sec. Users per second: 793
# shape of item_weights: (493, 25975)
# EvaluatorHoldout: Processed 493 ( 100.00% ) in 0.94 sec. Users per second: 522
# shape of item_weights: (493, 25975)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-0454dd7f3339> in <module>
#      90                 MAP_top_model_per_group[group_id] += results[cutoff]["MAP"]
#      91
# ---> 92                 results, _ = evaluator_p3_rp3.evaluateRecommender(hybridrecommender_2018_long)
#      93                 MAP_2018_long[group_id] += results[cutoff]["MAP"]
#      94
#
# ~/Desktop/Università/Recommender Systems/Recatommender-Systems-Challenge/Base/Evaluation/Evaluator.py in evaluateRecommender(self, recommender_object)
#     243         self._n_users_evaluated = 0
#     244
# --> 245         results_dict = self._run_evaluation_on_selected_users(recommender_object, self.users_to_evaluate)
#     246
#     247
#
# ~/Desktop/Università/Recommender Systems/Recatommender-Systems-Challenge/Base/Evaluation/Evaluator.py in _run_evaluation_on_selected_users(self, recommender_object, users_to_evaluate, block_size)
#     442
#     443             # Compute predictions for a batch of users using vectorization, much more efficient than computing it one at a time
# --> 444             recommended_items_batch_list, scores_batch = recommender_object.recommend(test_user_batch_array,
#     445                                                                       remove_seen_flag=self.exclude_seen,
#     446                                                                       cutoff = self.max_cutoff,
#
# ~/Desktop/Università/Recommender Systems/Recatommender-Systems-Challenge/Base/BaseRecommender.py in recommend(self, user_id_array, cutoff, remove_seen_flag, items_to_compute, remove_top_pop_flag, remove_custom_items_flag, return_scores)
#     126         # Compute the scores using the model-specific function
#     127         # Vectorize over all users in user_id_array
# --> 128         scores_batch = self._compute_item_score(user_id_array, items_to_compute=items_to_compute)
#     129
#     130
#
# ~/Desktop/Università/Recommender Systems/Recatommender-Systems-Challenge/KNN/ItemKNNScoresHybrid5Recommender.py in _compute_item_score(self, user_id_array, items_to_compute)
#      47         print('shape of item_weights:', item_weights_1.shape)
#      48
# ---> 49         item_weights = item_weights_1*self.first + item_weights_2*self.second + item_weights_3*self.third + item_weights_4*self.forth + item_weights_5*self.fifth
#      50
#      51         return item_weights
#
# AttributeError: 'ItemKNNScoresHybrid5Recommender' object has no attribute 'firth'

# %%
for index in range(0, 5):
    MAP_p3aplha_rp3beta_per_group[index] /= 5
    MAP_p3aplha_rp3beta_with_als_per_group[index] /= 5
    MAP_top_model_als_per_group[index] /= 5
    MAP_top_model_per_group[index] /= 5
    MAP_2018_long[index] /= 5
    MAP_2018_short[index] /= 5
    MAP_2018_seq[index] /= 5

# %%
import matplotlib.pyplot as pyplot
# %matplotlib inline  
pyplot.figure(figsize=(15,10))
pyplot.plot(MAP_p3aplha_rp3beta_per_group, label="P3Aplha - RP3Beta")
pyplot.plot(MAP_p3aplha_rp3beta_with_als_per_group, label="P3Aplha - RP3Beta - ALS")
pyplot.plot(MAP_top_model_als_per_group, label="topModel als :O")
pyplot.plot(MAP_top_model_per_group, label="topModel :O")
pyplot.plot(MAP_2018_long, label="2018 long")
pyplot.plot(MAP_2018_short, label="2018 short")
pyplot.plot(MAP_2018_seq, label="2018 seq")

pyplot.ylabel('MAP')
pyplot.xlabel('User Group')
pyplot.legend()
pyplot.show()
