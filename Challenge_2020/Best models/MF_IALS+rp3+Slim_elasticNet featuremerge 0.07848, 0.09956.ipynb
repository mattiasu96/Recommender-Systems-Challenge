# %% [markdown]
# # Data loading
# Next cells are used to load the data we need.

# %%
import os

os.environ["MKL_NUM_THREADS"] = "1" # export MKL_NUM_THREADS=1

import pandas as pd
import numpy as np 
import scipy.sparse as sps
import sys
import matplotlib.pyplot as plt
sys.path.append('../../')

# %%
#data which contains users (row), items(col) and implicit interaction (data)
dataset = pd.read_csv('../data_train.csv')
dataset
# Out:
#          row    col  data
# 0          0  10080   1.0
# 1          0  19467   1.0
# 2          1   2665   1.0
# 3          1   7494   1.0
# 4          1  17068   1.0
# ...      ...    ...   ...
# 113263  7945   2476   1.0
# 113264  7945  12319   1.0
# 113265  7945  21384   1.0
# 113266  7946   8699   1.0
# 113267  7946  19178   1.0
#
# [113268 rows x 3 columns]

# %% [markdown]
# # Data pre-processing
# Pre-processing of data to check for missing users, items ecc...

# %%
users = dataset.row
items = dataset.col
data = dataset.data
URM_all = sps.coo_matrix((data, (users, items)))
URM_all = URM_all.tocsr() #fast row access -> fast access to users 
URM_all.shape
# Out:
# (7947, 25975)

# %%
ICM_df = pd.read_csv('../data_ICM_title_abstract.csv')
ICM_df
# Out:
#           row    col      data
# 0           0   1185  1.015524
# 1           0   2507  0.459024
# 2           0   3534  0.227742
# 3           0   8766  0.501549
# 4           0  10862  0.297011
# ...       ...    ...       ...
# 490686  25974  12554  0.963016
# 490687  25974  13003  0.104613
# 490688  25974  16236  0.118760
# 490689  25974  18797  0.363301
# 490690  25974  19629  0.129141
#
# [490691 rows x 3 columns]

# %%
items = ICM_df.row
features = ICM_df.col
data = ICM_df.data
ICM_all = sps.coo_matrix((data, (items, features)))
ICM_all = ICM_all.tocsr() #fast row access -> fast access to users 
ICM_all.shape
# Out:
# (25975, 20000)

# %%
from Base.Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.8)
evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
# Out:
# Warning: 62 (0.78 %) of 7947 users have no train items
# Warning: 2303 (28.98 %) of 7947 users have no sampled items

# %%
from MatrixFactorization.IALSRecommender_implicit import IALSRecommender_implicit

#Trial 22 finished with value: 0.07502862236249128 and parameters: {'n_factors': 867, 'regularization': 0.7451746230098858, 'iterations': 74, 'weight': 0.5512468009549221}. Best is trial 22 with value: 0.07502862236249128.[0m
#printing self map vector:  [0.07496821 0.07736574 0.07275191]
#printing MAP:  0.07502862236249128

#current best parameters. Tune again near these values
#printing MAP:  0.07395163955000743
#{'n_factors': 767, 'regularization': 0.6762816208423306, 'iterations': 69, 'weight': 0.5686851029710857}

#{'n_factors': 779, 'regularization': 0.41829264231590485, 'iterations': 72, 'weight': 0.533979793083854}

URM_train_ICM_all_IALS = sps.vstack([URM_all*(1-0.5293971458364172), ICM_all.T*0.5293971458364172])
recommender_IALS = IALSRecommender_implicit(URM_train_ICM_all_IALS)
recommender_IALS.fit(n_factors = 768, regularization = 0.4489004525533907, iterations=76)
# Out:
# Recommender_Base_Class: URM Detected 2 (0.01 %) cold users.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=76.0), HTML(value='')))

# %%
from GraphBased.RP3betaRecommender import RP3betaRecommender
#already 3 crossed validated these values
URM_train_ICM_all_RP3 = sps.vstack([URM_all, ICM_all.T])
recommender_rp3Beta = RP3betaRecommender(URM_train_ICM_all_RP3)
recommender_rp3Beta.fit(topK=207, alpha = 0.36128728066686633, beta=0.26052832791376884, implicit = False) 
#recommender_rp3Beta.URM_train = URM_train
# Out:
# RP3betaRecommender: URM Detected 2 (0.01 %) cold users.

# %%
from SLIM_ElasticNet.SLIMElasticNetRecommender import SLIMElasticNetRecommender

URM_train_ICM_all_SLIM = sps.vstack([URM_all*(1-0.421), ICM_all.T*0.421])
recommender_SLIM = SLIMElasticNetRecommender(URM_train_ICM_all_SLIM)
recommender_SLIM.fit(topK=996, alpha = 0.000182, l1_ratio = 4.459e-06)
recommender_SLIM.W_sparse.data = np.power(recommender_SLIM.W_sparse.data, 0.8546)
# Out:
# SLIMElasticNetRecommender: URM Detected 2 (0.01 %) cold users.
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.001933749415911734, tolerance: 0.0008219736628234386
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0011172782396897674, tolerance: 0.0005707712844014168
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00125123281031847, tolerance: 0.0006786418962292373
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0042037805542349815, tolerance: 0.0010425166692584753
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0016008897218853235, tolerance: 0.0003115119761787355
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0004316576523706317, tolerance: 8.584411261836067e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0008069129544310272, tolerance: 0.00035722440225072205
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0025103027001023293, tolerance: 0.0014763036742806435
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004428036045283079, tolerance: 0.0012731042224913836
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002560768974944949, tolerance: 0.0013173326151445508
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00838850624859333, tolerance: 0.0022235815413296223
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02610844559967518, tolerance: 0.003152445424348116
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0045769172720611095, tolerance: 0.0008739424520172179
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0004950332804583013, tolerance: 0.0002546148607507348
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0007108094869181514, tolerance: 0.0005001763929612935
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0007273784722201526, tolerance: 0.00024509677314199507
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0036757178604602814, tolerance: 0.0012134457938373089
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003543025581166148, tolerance: 0.0015368710737675428
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006340791005641222, tolerance: 0.00020043429685756564
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03348865360021591, tolerance: 0.0029731113463640213
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7.909836858743802e-05, tolerance: 6.0442958783824e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00039761944208294153, tolerance: 0.0002552639343775809
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00432954216375947, tolerance: 0.0015752706676721573
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0004476313479244709, tolerance: 0.0002387262211414054
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06585036963224411, tolerance: 0.0034611655864864588
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002122103003785014, tolerance: 0.0009729083976708353
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010365108028054237, tolerance: 0.0018557090079411864
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004523004870861769, tolerance: 0.0011931806802749634
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0001944033137988299, tolerance: 9.802176646189764e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00010073052544612437, tolerance: 9.624359518056735e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0011101497802883387, tolerance: 0.0001353389088762924
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003936877474188805, tolerance: 0.001477984362281859
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00025558401830494404, tolerance: 0.00020629951904993504
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005485106259584427, tolerance: 0.0020352331921458244
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0014983577420935035, tolerance: 0.0009760587709024549
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0082321148365736, tolerance: 0.0014600566355511546
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11106616258621216, tolerance: 0.004060257691890001
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0023963404819369316, tolerance: 0.0013088833075016737
#   model = cd_fast.sparse_enet_coordinate_descent(
# SLIMElasticNetRecommender: Processed 23274 ( 89.60% ) in 30.01 min. Items per second: 12.93
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0010622151894494891, tolerance: 0.0005210241652093828
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0002920977130997926, tolerance: 0.0001529037836007774
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1198461726307869, tolerance: 0.002609488321468234
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002718549221754074, tolerance: 0.002653030911460519
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013466139324009418, tolerance: 0.002627419540658593
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09720926731824875, tolerance: 0.002236056374385953
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00031975374440662563, tolerance: 0.0001435626036254689
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16269579529762268, tolerance: 0.013205056078732014
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0015257273335009813, tolerance: 0.0007358508883044124
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0007722346344962716, tolerance: 0.00022174433979671448
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0016598007641732693, tolerance: 8.42883819132112e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03825164958834648, tolerance: 0.00295088323764503
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00025127854314632714, tolerance: 0.00023406490799970925
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0296926312148571, tolerance: 0.00167048757430166
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8.524458826286718e-05, tolerance: 3.487366120680235e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1257064789533615, tolerance: 0.008016743697226048
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0008176090777851641, tolerance: 0.00036857122904621065
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.028750719502568245, tolerance: 0.0018809903413057327
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.2120165824890137, tolerance: 0.007426316849887371
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0025035792496055365, tolerance: 0.0007116304477676749
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006740546668879688, tolerance: 0.00022016357979737222
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0005919356481172144, tolerance: 0.00016123570094350725
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00465863524004817, tolerance: 0.0007731912191957235
#   model = cd_fast.sparse_enet_coordinate_descent(
# SLIMElasticNetRecommender: Processed 25975 ( 100.00% ) in 33.89 min. Items per second: 12.77

# %%
from KNN.ItemKNNScoresHybridNRecommender import ItemKNNScoresHybridNRecommender
URM_train_ICM_all = sps.vstack([URM_all, ICM_all.T])

hybrid = ItemKNNScoresHybridNRecommender(URM_train_ICM_all, [recommender_IALS,recommender_rp3Beta,recommender_SLIM], 3)
hybrid.fit([ 0.13075755984794613,0.8106451806910928, 0.10545116633705816])
#evaluator_validation.evaluateRecommender(hybrid)
# Out:
# ItemKNNScoresHybridNRecommender: URM Detected 2 (0.01 %) cold users.
# number of recommenders: 3

# %%
test_users = pd.read_csv('../data_target_users_test.csv')
test_users
# Out:
#       user_id
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
# ...       ...
# 7939     7942
# 7940     7943
# 7941     7944
# 7942     7945
# 7943     7946
#
# [7944 rows x 1 columns]

# %%
user_id = test_users['user_id']
recommendations = hybrid.recommend(user_id,cutoff = 10)

# %%
for index in range(len(recommendations)):
    recommendations[index]=np.array(recommendations[index])
    
print(len(recommendations))

test_users['item_list']= recommendations
test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])

test_users
test_users.to_csv('submission.csv', index=False)
# Out:
# 7944
