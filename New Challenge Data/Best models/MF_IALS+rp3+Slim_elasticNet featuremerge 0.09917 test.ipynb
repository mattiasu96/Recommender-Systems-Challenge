# %% [markdown]
# # Data loading
# Next cells are used to load the data we need.

# %%
import os

os.environ["MKL_NUM_THREADS"] = "1" # export MKL_NUM_THREADS=1

import pandas as pd
import numpy as np 
import scipy.sparse as sps
import sys
import matplotlib.pyplot as plt
sys.path.append('../../')

# %%
#data which contains users (row), items(col) and implicit interaction (data)
dataset = pd.read_csv('../data_train.csv')
dataset
# Out:
#          row    col  data
# 0          0  10080   1.0
# 1          0  19467   1.0
# 2          1   2665   1.0
# 3          1   7494   1.0
# 4          1  17068   1.0
# ...      ...    ...   ...
# 113263  7945   2476   1.0
# 113264  7945  12319   1.0
# 113265  7945  21384   1.0
# 113266  7946   8699   1.0
# 113267  7946  19178   1.0
#
# [113268 rows x 3 columns]

# %% [markdown]
# # Data pre-processing
# Pre-processing of data to check for missing users, items ecc...

# %%
users = dataset.row
items = dataset.col
data = dataset.data
URM_all = sps.coo_matrix((data, (users, items)))
URM_all = URM_all.tocsr() #fast row access -> fast access to users 
URM_all.shape
# Out:
# (7947, 25975)

# %%
ICM_df = pd.read_csv('../data_ICM_title_abstract.csv')
ICM_df
# Out:
#           row    col      data
# 0           0   1185  1.015524
# 1           0   2507  0.459024
# 2           0   3534  0.227742
# 3           0   8766  0.501549
# 4           0  10862  0.297011
# ...       ...    ...       ...
# 490686  25974  12554  0.963016
# 490687  25974  13003  0.104613
# 490688  25974  16236  0.118760
# 490689  25974  18797  0.363301
# 490690  25974  19629  0.129141
#
# [490691 rows x 3 columns]

# %%
items = ICM_df.row
features = ICM_df.col
data = ICM_df.data
ICM_all = sps.coo_matrix((data, (items, features)))
ICM_all = ICM_all.tocsr() #fast row access -> fast access to users 
ICM_all.shape
# Out:
# (25975, 20000)

# %%
from Base.Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.8)
evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
# Out:
# Warning: 55 (0.69 %) of 7947 users have no train items
# Warning: 2348 (29.55 %) of 7947 users have no sampled items

# %%
from MatrixFactorization.IALSRecommender_implicit import IALSRecommender_implicit

#Trial 22 finished with value: 0.07502862236249128 and parameters: {'n_factors': 867, 'regularization': 0.7451746230098858, 'iterations': 74, 'weight': 0.5512468009549221}. Best is trial 22 with value: 0.07502862236249128.[0m
#printing self map vector:  [0.07496821 0.07736574 0.07275191]
#printing MAP:  0.07502862236249128

#current best parameters. Tune again near these values
#printing MAP:  0.07395163955000743
#{'n_factors': 767, 'regularization': 0.6762816208423306, 'iterations': 69, 'weight': 0.5686851029710857}

#{'n_factors': 779, 'regularization': 0.41829264231590485, 'iterations': 72, 'weight': 0.533979793083854}

URM_train_ICM_all_IALS = sps.vstack([URM_all*(1-0.5293971458364172), ICM_all.T*0.5293971458364172])
recommender_IALS = IALSRecommender_implicit(URM_train_ICM_all_IALS)
recommender_IALS.fit(n_factors = 768, regularization = 0.4489004525533907, iterations=76)
# Out:
# Recommender_Base_Class: URM Detected 2 (0.01 %) cold users.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=76.0), HTML(value='')))

# %%
from GraphBased.RP3betaRecommender import RP3betaRecommender
#already 3 crossed validated these values
URM_train_ICM_all_RP3 = sps.vstack([URM_all, ICM_all.T])
recommender_rp3Beta = RP3betaRecommender(URM_train_ICM_all_RP3)
recommender_rp3Beta.fit(topK=291, alpha = 0.39433313113766405, beta=0.27467923612192335, implicit = False) 
#recommender_rp3Beta.URM_train = URM_train
# Out:
# RP3betaRecommender: URM Detected 2 (0.01 %) cold users.

# %%
from SLIM_ElasticNet.SLIMElasticNetRecommender import SLIMElasticNetRecommender

URM_train_ICM_all_SLIM = sps.vstack([URM_all*(1-0.421), ICM_all.T*0.421])
recommender_SLIM = SLIMElasticNetRecommender(URM_train_ICM_all_SLIM)
recommender_SLIM.fit(topK=996, alpha = 0.000182, l1_ratio = 4.459e-06)
recommender_SLIM.W_sparse.data = np.power(recommender_SLIM.W_sparse.data, 0.8546)
# Out:
# SLIMElasticNetRecommender: URM Detected 2 (0.01 %) cold users.
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.001372243743389845, tolerance: 0.0005707712844014168
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00021992427355144173, tolerance: 0.00011493572674226016
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0013902480714023113, tolerance: 0.0006786418962292373
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005681492388248444, tolerance: 0.0010425166692584753
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0004316667909733951, tolerance: 8.584411261836067e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0007995728519745171, tolerance: 0.00035722440225072205
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006277482025325298, tolerance: 0.00039366239798255265
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00038132283953018486, tolerance: 0.0003577661409508437
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00011450929014245048, tolerance: 6.548273813677952e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0003403550072107464, tolerance: 9.99471012619324e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004033427685499191, tolerance: 0.0013173326151445508
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02509271539747715, tolerance: 0.0022235815413296223
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03492679446935654, tolerance: 0.003152445424348116
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004576678853482008, tolerance: 0.0008739424520172179
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00039357427158392966, tolerance: 0.0002546148607507348
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04085031896829605, tolerance: 0.0038821203634142876
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.000454498891485855, tolerance: 0.00021323547116480768
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0024252349976450205, tolerance: 0.0006693197647109628
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.011738894507288933, tolerance: 0.001950539881363511
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005042653530836105, tolerance: 0.0012134457938373089
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005271099507808685, tolerance: 0.0015368710737675428
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0007731096702627838, tolerance: 0.00020043429685756564
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.011437293142080307, tolerance: 0.0029731113463640213
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.691121961921453e-05, tolerance: 6.0442958783824e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00036543214810080826, tolerance: 0.0002552639343775809
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005169568583369255, tolerance: 0.0015752706676721573
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00044625901500694454, tolerance: 0.0002387262211414054
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0019138379720970988, tolerance: 0.001505881897173822
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.06408616155385971, tolerance: 0.0034611655864864588
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0015710426960140467, tolerance: 0.0009729083976708353
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01090590562671423, tolerance: 0.0018557090079411864
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0001835878356359899, tolerance: 9.802176646189764e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0013719146372750401, tolerance: 0.0011541977291926742
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0011084341676905751, tolerance: 0.0001353389088762924
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0032982362899929285, tolerance: 0.001477984362281859
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00026428038836456835, tolerance: 0.00020629951904993504
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009408697485923767, tolerance: 0.0020352331921458244
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0025891961995512247, tolerance: 0.0009760587709024549
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08739616721868515, tolerance: 0.004060257691890001
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004098999314010143, tolerance: 0.0022642984986305237
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0002645791682880372, tolerance: 0.0001529037836007774
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11331721395254135, tolerance: 0.002609488321468234
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0076141199097037315, tolerance: 0.002653030911460519
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016458652913570404, tolerance: 0.002627419540658593
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1525457799434662, tolerance: 0.002236056374385953
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00023922893160488456, tolerance: 0.0001435626036254689
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08192756026983261, tolerance: 0.013205056078732014
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0008204432087950408, tolerance: 0.00022174433979671448
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0017534091603010893, tolerance: 8.42883819132112e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03696257248520851, tolerance: 0.00295088323764503
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00027239692281000316, tolerance: 0.00023406490799970925
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.035408660769462585, tolerance: 0.00167048757430166
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0009320898097939789, tolerance: 0.0005163168534636497
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003021100303158164, tolerance: 0.0006732761394232512
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.294920164393261e-05, tolerance: 7.357281720032915e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# SLIMElasticNetRecommender: Processed 25195 ( 97.00% ) in 30.00 min. Items per second: 13.99
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.493612014921382e-05, tolerance: 3.487366120680235e-05
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15898866951465607, tolerance: 0.008016743697226048
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.030729791149497032, tolerance: 0.0018809903413057327
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.404031991958618, tolerance: 0.007426316849887371
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003793638665229082, tolerance: 0.0007116304477676749
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006843985174782574, tolerance: 0.00022016357979737222
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0006711480091325939, tolerance: 0.00016123570094350725
#   model = cd_fast.sparse_enet_coordinate_descent(
# C:\Users\matti\anaconda3\envs\my_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:512: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.003390622092410922, tolerance: 0.0007731912191957235
#   model = cd_fast.sparse_enet_coordinate_descent(
# SLIMElasticNetRecommender: Processed 25975 ( 100.00% ) in 30.93 min. Items per second: 14.00

# %%
from KNN.ItemKNNScoresHybridNRecommender import ItemKNNScoresHybridNRecommender
URM_train_ICM_all = sps.vstack([URM_all, ICM_all.T])

hybrid = ItemKNNScoresHybridNRecommender(URM_train_ICM_all, [recommender_IALS,recommender_rp3Beta,recommender_SLIM], 3)
hybrid.fit([0.14066584548860117,0.7208499259849473, 0.10748917695634556])
#evaluator_validation.evaluateRecommender(hybrid)
# Out:
# ItemKNNScoresHybridNRecommender: URM Detected 2 (0.01 %) cold users.
# number of recommenders: 3

# %%
test_users = pd.read_csv('../data_target_users_test.csv')
test_users
# Out:
#       user_id
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
# ...       ...
# 7939     7942
# 7940     7943
# 7941     7944
# 7942     7945
# 7943     7946
#
# [7944 rows x 1 columns]

# %%
user_id = test_users['user_id']
recommendations = hybrid.recommend(user_id,cutoff = 10)

# %%
for index in range(len(recommendations)):
    recommendations[index]=np.array(recommendations[index])
    
print(len(recommendations))

test_users['item_list']= recommendations
test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])

test_users
test_users.to_csv('submission.csv', index=False)
# Out:
# 7944
