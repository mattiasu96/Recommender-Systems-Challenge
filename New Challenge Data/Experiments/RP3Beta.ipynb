# %% [markdown]
# # Data loading
# Next cells are used to load the data we need.

# %%
import pandas as pd
import numpy as np 
import scipy.sparse as sps
import os
import sys
import matplotlib.pyplot as plt
sys.path.append('..')

# %%
#data which contains users (row), items(col) and implicit interaction (data)
dataset = pd.read_csv('data_train.csv')
dataset
# Out:
#          row    col  data
# 0          0  10080   1.0
# 1          0  19467   1.0
# 2          1   2665   1.0
# 3          1   7494   1.0
# 4          1  17068   1.0
# ...      ...    ...   ...
# 113263  7945   2476   1.0
# 113264  7945  12319   1.0
# 113265  7945  21384   1.0
# 113266  7946   8699   1.0
# 113267  7946  19178   1.0
#
# [113268 rows x 3 columns]

# %% [markdown]
# # Data pre-processing
# Pre-processing of data to check for missing users, items ecc...

# %%
users = dataset.row
items = dataset.col
data = dataset.data
URM_all = sps.coo_matrix((data, (users, items)))
URM_all = URM_all.tocsr() #fast row access -> fast access to users 
URM_all.shape
# Out:
# (7947, 25975)

# %%
from Base.Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.85)

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
# Out:
# Warning: 36 (0.45 %) of 7947 users have no train items
# Warning: 2891 (36.38 %) of 7947 users have no sampled items

# %%
from GraphBased.RP3betaRecommender import RP3betaRecommender

recommender = RP3betaRecommender(URM_train)
# Out:
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.

# %%
x_tick = []
collaborative_MAP = []
max_map = 0
x_tick_max = ""

for topK in [10,40,70,75,100]:
    for alpha in [0.1,0.2,0.4,0.45]:
        for beta in [0.1,0.2,0.4,0.45]:
            x_tick.append("topk {}, alpha{}, beta{}".format(topK,alpha,beta))

            recommender = RP3betaRecommender(URM_train)

            recommender.fit(topK=topK, alpha=alpha, beta=beta, implicit=True)

            result_dict, _ = evaluator_validation.evaluateRecommender(recommender)

            collaborative_MAP.append(result_dict[10]["MAP"])

            if result_dict[10]["MAP"] > max_map:
                max_map = result_dict[10]["MAP"]
                x_tick_max = "topk {}, alpha{}, beta{}".format(topK,alpha,beta)

print("********")
print(max_map)
print(x_tick_max)
# Out:
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.21 sec. Users per second: 1574
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.33 sec. Users per second: 1520
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.04 sec. Users per second: 1661
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.37 sec. Users per second: 1502
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.22 sec. Users per second: 1571
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.38 sec. Users per second: 1495
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.37 sec. Users per second: 1500
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.18 sec. Users per second: 1588
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.08 sec. Users per second: 1643
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.11 sec. Users per second: 1624
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.09 sec. Users per second: 1635
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.13 sec. Users per second: 1618
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.03 sec. Users per second: 1671
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.14 sec. Users per second: 1609
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.11 sec. Users per second: 1627
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.04 sec. Users per second: 1665
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.11 sec. Users per second: 1627
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.06 sec. Users per second: 1653
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.39 sec. Users per second: 1491
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.20 sec. Users per second: 1582
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.14 sec. Users per second: 1608
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 5.03 sec. Users per second: 1006
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.15 sec. Users per second: 1603
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.83 sec. Users per second: 1321
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.59 sec. Users per second: 1409
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.23 sec. Users per second: 1566
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.25 sec. Users per second: 1555
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.26 sec. Users per second: 1550
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.36 sec. Users per second: 1506
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.52 sec. Users per second: 1435
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.19 sec. Users per second: 1583
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.19 sec. Users per second: 1586
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.24 sec. Users per second: 1562
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.33 sec. Users per second: 1520
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.28 sec. Users per second: 1541
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.48 sec. Users per second: 1452
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.68 sec. Users per second: 1372
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.36 sec. Users per second: 1507
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.34 sec. Users per second: 1514
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.24 sec. Users per second: 1559
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 4.48 sec. Users per second: 1129
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.17 sec. Users per second: 1596
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.20 sec. Users per second: 1581
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.20 sec. Users per second: 1579
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.15 sec. Users per second: 1608
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.35 sec. Users per second: 1509
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.23 sec. Users per second: 1563
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.20 sec. Users per second: 1582
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.21 sec. Users per second: 1576
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.12 sec. Users per second: 1623
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.21 sec. Users per second: 1577
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.37 sec. Users per second: 1501
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.12 sec. Users per second: 1623
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.40 sec. Users per second: 1487
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.28 sec. Users per second: 1541
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.19 sec. Users per second: 1585
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.20 sec. Users per second: 1578
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.37 sec. Users per second: 1502
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.19 sec. Users per second: 1584
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.18 sec. Users per second: 1590
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.10 sec. Users per second: 1631
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.18 sec. Users per second: 1588
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.50 sec. Users per second: 1443
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.22 sec. Users per second: 1572
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.19 sec. Users per second: 1584
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.14 sec. Users per second: 1608
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.23 sec. Users per second: 1567
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.56 sec. Users per second: 1418
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.18 sec. Users per second: 1588
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.19 sec. Users per second: 1586
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.19 sec. Users per second: 1586
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.70 sec. Users per second: 1367
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.44 sec. Users per second: 1468
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.26 sec. Users per second: 1552
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.29 sec. Users per second: 1539
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.27 sec. Users per second: 1548
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.22 sec. Users per second: 1572
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.38 sec. Users per second: 1494
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.22 sec. Users per second: 1573
# RP3betaRecommender: URM Detected 36 (0.45 %) cold users.
# RP3betaRecommender: URM Detected 1999 (7.70 %) cold items.
# EvaluatorHoldout: Processed 5056 ( 100.00% ) in 3.21 sec. Users per second: 1574
# ********
# 0.053441024209877265
# topk 75, alpha0.4, beta0.1

# %%
import operator
index, value = max(enumerate(collaborative_MAP), key=operator.itemgetter(1))
print(index, value)
parameters = x_tick[index]
print(parameters)

# %%
import matplotlib.ticker as ticker

fig, ax = plt.subplots(1, 1, figsize=(15, 9))
plt.plot(x_tick, collaborative_MAP, label="Collaborative")
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.001))
plt.ylabel('MAP')
plt.xlabel('TopK')
plt.xticks(rotation='vertical')
plt.show()

# %%
test_users = pd.read_csv('data_target_users_test.csv')
test_users

# %%
recommender = RP3betaRecommender(URM_all)

recommender.fit(topK=70, alpha=0.4, beta=0.2, implicit=True)

user_id = test_users['user_id']
recommendations = recommender.recommend(user_id,cutoff = 10)

# %%
for index in range(len(recommendations)):
    #print(element)
    recommendations[index]=np.array(recommendations[index])
    #print(type(element))
print(len(recommendations))

# %%
test_users['item_list']= recommendations
#test_users['item_list'] =  test_users['item_list'].apply(lambda x: x.replace('[','').replace(']','')) 
test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])

#convert the string columns to int
#test_users['item_list'] = test_users['item_list'].astype(int)
test_users
test_users.to_csv('submission.csv', index=False)
